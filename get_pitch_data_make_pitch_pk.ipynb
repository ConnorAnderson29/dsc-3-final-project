# %% [markdown]
# # Getting Pitch-level Data
# The goal is to obtain data related to a single pitch in an MLB game, given our decided parameters. For example, "the 2nd pitch of the 3rd at-bat of the bottom of the first inning" (to demonstrate the granularity).

# %% [markdown]
# ---

# %% [markdown]
# ## Libraries

# %%
import pandas as pd # Dataframes
from pandas.io.json import json_normalize # JSON wrangler

import statsapi # Python wrapper MLB data API

from sqlalchemy import create_engine # SQL helper
import psycopg2 as psql #PostgreSQL DBs

# %% [markdown]
# ---

# %% [markdown]
# ## Data Retrieval
#
# In order to retrieval publicly available data from the Major League Baseball Stats API, we will use a module called `statsapi`.

# %% [markdown]
# ### 1. Determine list of games

# %%
list_game_pks = [565997]

# %% [markdown]
# ### 2. Retrieve play-by-play data for game(s).

# %%
# Get one game from API
curr_game = statsapi.get('game_playByPlay',{'gamePk':list_game_pks[0]})

# %% [markdown]
# ### 3. Extract play-by-play data and store into dataframe.

# %%
# Only care about the allPlays key 
curr_plays = curr_game.get('allPlays')

# Coerce all plays into a df
curr_plays_df = json_normalize(curr_plays)

# %%
###################################
# Build target table
###################################

# Append dicts to this list
list_for_new_df = []

# Data from allPlays
ap_sel_cols = ['about.atBatIndex', 'matchup.batSide.code', 'matchup.pitchHand.code', 'count.balls'
              ,'count.strikes', 'count.outs']

# Data from playEvents
plev_sel_cols = ['details.type.code', 'details.type.description', 
            'details.call.code', 'details.call.description', 
            'details.isBall', 'isPitch', 'details.isStrike'
            ,'pitchData.breaks.breakAngle'
            ,'pitchData.breaks.breakLength', 'pitchData.breaks.breakY'
            ,'pitchData.breaks.spinDirection', 'pitchData.breaks.spinRate'
            ,'pitchData.coordinates.aX'
            , 'pitchData.coordinates.aY','pitchData.coordinates.aZ', 'pitchData.coordinates.pX'
            , 'pitchData.coordinates.pZ', 'pitchData.coordinates.pfxX', 'pitchData.coordinates.pfxZ'
            , 'pitchData.coordinates.vX0', 'pitchData.coordinates.vY0', 'pitchData.coordinates.vZ0'
            , 'pitchData.coordinates.x', 'pitchData.coordinates.x0', 'pitchData.coordinates.y'
            , 'pitchData.coordinates.y0','pitchData.coordinates.z0', 'pitchData.endSpeed'
            , 'pitchData.startSpeed', 'pitchNumber'
           ]

# Now go through each row. If there is nested list, json_normalize it
#for index, row in test_df.head(2).iterrows(): #Just using first 2 rows for testing
for index, row in curr_plays_df.iterrows(): #Just using first 2 rows for testing
    
    # saw playEvents is a nested list, so json_normalize it
    play_events_df = json_normalize(row['playEvents'])
    
#     # look at runners
#     runners_df = json_normalize(row['runners'])
        
    # Loop through THIS NESTED dataframe and NOW build the row for the new df    
    for plev_ind, plev_row in play_events_df.iterrows():
  
        # Instantiate new dict, which will be a single row in target df
        curr_dict = {}

        # Loop through each list, adding their respective values to curr_dict
        for col_ap in ap_sel_cols:
            curr_dict[col_ap] = row[col_ap]
    
        for col_plev in plev_sel_cols:
            curr_dict[col_plev] = plev_row[col_plev]
        
        # collect row dictionary into list
        list_for_new_df.append(curr_dict)

# %%
# Proof of concept on target dataframe
pitches_df = pd.DataFrame(list_for_new_df)

pitches_df.head(10).T
# Out:
#                                                  0                  1  \
# about.atBatIndex                                 0                  0
# count.balls                                      3                  3
# count.outs                                       1                  1
# count.strikes                                    3                  3
# details.call.code                                B                  B
# details.call.description             Ball - Called      Ball - Called
# details.isBall                                True               True
# details.isStrike                             False              False
# details.type.code                               FF                 FT
# details.type.description        Four-Seam Fastball  Two-Seam Fastball
# isPitch                                       True               True
# matchup.batSide.code                             R                  R
# matchup.pitchHand.code                           L                  L
# pitchData.breaks.breakAngle                     36               37.2
# pitchData.breaks.breakLength                   4.8                7.2
# pitchData.breaks.breakY                         24                 24
# pitchData.breaks.spinDirection                 146                126
# pitchData.breaks.spinRate                     2303               2262
# pitchData.coordinates.aX                     12.55              16.89
# pitchData.coordinates.aY                     26.39               26.1
# pitchData.coordinates.aZ                    -13.99             -20.27
# pitchData.coordinates.pX                      1.48               1.61
# pitchData.coordinates.pZ                      1.58               2.54
# pitchData.coordinates.pfxX                    8.38              11.27
# pitchData.coordinates.pfxZ                   12.13               7.94
# pitchData.coordinates.vX0                    -5.79              -6.22
# pitchData.coordinates.vY0                  -122.28            -122.19
# pitchData.coordinates.vZ0                    -6.67              -3.37
# pitchData.coordinates.x                      60.67              55.45
# pitchData.coordinates.x0                       2.8               2.74
# pitchData.coordinates.y                     196.16              170.3
# pitchData.coordinates.y0                        50                 50
# pitchData.coordinates.z0                      5.57               5.69
# pitchData.endSpeed                            76.4               76.3
# pitchData.startSpeed                          84.3               84.2
# pitchNumber                                      1                  2
#
#                                                 2              3  \
# about.atBatIndex                                0              0
# count.balls                                     3              3
# count.outs                                      1              1
# count.strikes                                   3              3
# details.call.code                               S              B
# details.call.description        Strike - Swinging  Ball - Called
# details.isBall                              False           True
# details.isStrike                             True          False
# details.type.code                              FT             CH
# details.type.description        Two-Seam Fastball       Changeup
# isPitch                                      True           True
# matchup.batSide.code                            R              R
# matchup.pitchHand.code                          L              L
# pitchData.breaks.breakAngle                  34.8           34.8
# pitchData.breaks.breakLength                    6            8.4
# pitchData.breaks.breakY                        24             24
# pitchData.breaks.spinDirection                139            125
# pitchData.breaks.spinRate                    2358           2328
# pitchData.coordinates.aX                    14.52          16.58
# pitchData.coordinates.aY                    26.31          23.68
# pitchData.coordinates.aZ                   -16.71         -20.53
# pitchData.coordinates.pX                    -0.23           0.53
# pitchData.coordinates.pZ                     1.67           1.19
# pitchData.coordinates.pfxX                   9.54          12.07
# pitchData.coordinates.pfxZ                  10.17           8.48
# pitchData.coordinates.vX0                   -9.84          -8.08
# pitchData.coordinates.vY0                 -123.08        -116.93
# pitchData.coordinates.vZ0                   -5.83          -5.93
# pitchData.coordinates.x                    125.65          96.61
# pitchData.coordinates.x0                      2.6           2.48
# pitchData.coordinates.y                    193.72         206.66
# pitchData.coordinates.y0                       50             50
# pitchData.coordinates.z0                      5.5           5.71
# pitchData.endSpeed                             77           73.4
# pitchData.startSpeed                         84.9           80.8
# pitchNumber                                     3              4
#
#                                                 4                   5  \
# about.atBatIndex                                0                   0
# count.balls                                     3                   3
# count.outs                                      1                   1
# count.strikes                                   3                   3
# details.call.code                               S                   S
# details.call.description        Strike - Swinging   Strike - Swinging
# details.isBall                              False               False
# details.isStrike                             True                True
# details.type.code                              FT                  FF
# details.type.description        Two-Seam Fastball  Four-Seam Fastball
# isPitch                                      True                True
# matchup.batSide.code                            R                   R
# matchup.pitchHand.code                          L                   L
# pitchData.breaks.breakAngle                  28.8                31.2
# pitchData.breaks.breakLength                    6                 4.8
# pitchData.breaks.breakY                        24                  24
# pitchData.breaks.spinDirection                141                 142
# pitchData.breaks.spinRate                    2234                2353
# pitchData.coordinates.aX                     12.3               12.11
# pitchData.coordinates.aY                    24.18               26.89
# pitchData.coordinates.aZ                   -18.55              -17.35
# pitchData.coordinates.pX                    -0.15                1.43
# pitchData.coordinates.pZ                     2.66                2.43
# pitchData.coordinates.pfxX                   7.92                7.54
# pitchData.coordinates.pfxZ                   8.78                9.23
# pitchData.coordinates.vX0                   -9.12               -5.84
# pitchData.coordinates.vY0                 -123.69             -126.23
# pitchData.coordinates.vZ0                   -3.51               -4.25
# pitchData.coordinates.x                    122.61               62.49
# pitchData.coordinates.x0                     2.55                 2.8
# pitchData.coordinates.y                    167.13              173.25
# pitchData.coordinates.y0                       50                  50
# pitchData.coordinates.z0                     5.65                5.54
# pitchData.endSpeed                             78                79.1
# pitchData.startSpeed                         85.2                86.9
# pitchNumber                                     5                   6
#
#                                                  6                   7  \
# about.atBatIndex                                 1                   1
# count.balls                                      2                   2
# count.outs                                       1                   1
# count.strikes                                    2                   2
# details.call.code                                S                   B
# details.call.description         Strike - Swinging       Ball - Called
# details.isBall                               False                True
# details.isStrike                              True               False
# details.type.code                               FF                  FF
# details.type.description        Four-Seam Fastball  Four-Seam Fastball
# isPitch                                       True                True
# matchup.batSide.code                             R                   R
# matchup.pitchHand.code                           L                   L
# pitchData.breaks.breakAngle                   34.8                25.2
# pitchData.breaks.breakLength                   4.8                 4.8
# pitchData.breaks.breakY                         24                  24
# pitchData.breaks.spinDirection                 144                 152
# pitchData.breaks.spinRate                     2293                2282
# pitchData.coordinates.aX                     13.12                 9.9
# pitchData.coordinates.aY                     25.34               26.16
# pitchData.coordinates.aZ                    -15.07              -16.65
# pitchData.coordinates.pX                      0.28                -0.8
# pitchData.coordinates.pZ                      1.62                 3.4
# pitchData.coordinates.pfxX                    8.47                6.33
# pitchData.coordinates.pfxZ                   11.04                9.92
# pitchData.coordinates.vX0                    -8.31               -9.69
# pitchData.coordinates.vY0                  -123.85             -124.61
# pitchData.coordinates.vZ0                    -6.53                -2.5
# pitchData.coordinates.x                      106.5              147.61
# pitchData.coordinates.x0                      2.58                2.32
# pitchData.coordinates.y                     195.08                 147
# pitchData.coordinates.y0                        50                  50
# pitchData.coordinates.z0                      5.56                5.79
# pitchData.endSpeed                            77.9                  78
# pitchData.startSpeed                          85.4                  86
# pitchNumber                                      1                   2
#
#                                                 8                   9
# about.atBatIndex                                1                   1
# count.balls                                     2                   2
# count.outs                                      1                   1
# count.strikes                                   2                   2
# details.call.code                               S                   S
# details.call.description        Strike - Swinging   Strike - Swinging
# details.isBall                              False               False
# details.isStrike                             True                True
# details.type.code                              FT                  FF
# details.type.description        Two-Seam Fastball  Four-Seam Fastball
# isPitch                                      True                True
# matchup.batSide.code                            R                   R
# matchup.pitchHand.code                          L                   L
# pitchData.breaks.breakAngle                  37.2                  18
# pitchData.breaks.breakLength                    6                 4.8
# pitchData.breaks.breakY                        24                  24
# pitchData.breaks.spinDirection                130                 159
# pitchData.breaks.spinRate                    2347                2261
# pitchData.coordinates.aX                    16.18                7.53
# pitchData.coordinates.aY                    27.38               27.41
# pitchData.coordinates.aZ                   -19.17              -17.33
# pitchData.coordinates.pX                     1.28               -0.62
# pitchData.coordinates.pZ                     2.92                3.77
# pitchData.coordinates.pfxX                  10.49                4.71
# pitchData.coordinates.pfxZ                   8.42                9.28
# pitchData.coordinates.vX0                   -6.59               -9.33
# pitchData.coordinates.vY0                 -124.14             -126.17
# pitchData.coordinates.vZ0                   -2.75               -1.25
# pitchData.coordinates.x                      68.1              140.82
# pitchData.coordinates.x0                     2.62                2.52
# pitchData.coordinates.y                    159.87              137.07
# pitchData.coordinates.y0                       50                  50
# pitchData.coordinates.z0                     5.66                5.67
# pitchData.endSpeed                           77.3                78.8
# pitchData.startSpeed                         85.5                  87
# pitchNumber                                     3                   4

# %%
pitches_df.tail().T
# Out:
#                                           360            361  \
# about.atBatIndex                           79             79
# count.balls                                 3              3
# count.outs                                  3              3
# count.strikes                               3              3
# details.call.code                           B              B
# details.call.description        Ball - Called  Ball - Called
# details.isBall                           True           True
# details.isStrike                        False          False
# details.type.code                          SL             SL
# details.type.description               Slider         Slider
# isPitch                                  True           True
# matchup.batSide.code                        R              R
# matchup.pitchHand.code                      R              R
# pitchData.breaks.breakAngle                12             12
# pitchData.breaks.breakLength              7.2              6
# pitchData.breaks.breakY                    24             24
# pitchData.breaks.spinDirection            128            141
# pitchData.breaks.spinRate                2062           2034
# pitchData.coordinates.aX                 4.41           4.48
# pitchData.coordinates.aY                   25          25.62
# pitchData.coordinates.aZ                -26.3          -24.1
# pitchData.coordinates.pX                  1.9          -0.22
# pitchData.coordinates.pZ                 1.08           0.73
# pitchData.coordinates.pfxX               2.77           2.77
# pitchData.coordinates.pfxZ               3.69           4.99
# pitchData.coordinates.vX0                8.25           3.96
# pitchData.coordinates.vY0             -125.24        -126.37
# pitchData.coordinates.vZ0               -6.89          -8.23
# pitchData.coordinates.x                 44.66         125.22
# pitchData.coordinates.x0                 -1.8          -2.16
# pitchData.coordinates.y                209.73         219.16
# pitchData.coordinates.y0                   50             50
# pitchData.coordinates.z0                 6.01           5.96
# pitchData.endSpeed                       79.7           80.2
# pitchData.startSpeed                     86.3             87
# pitchNumber                                 2              3
#
#                                                362            363  \
# about.atBatIndex                                79             79
# count.balls                                      3              3
# count.outs                                       3              3
# count.strikes                                    3              3
# details.call.code                                S              B
# details.call.description         Strike - Swinging  Ball - Called
# details.isBall                               False           True
# details.isStrike                              True          False
# details.type.code                               FF             SL
# details.type.description        Four-Seam Fastball         Slider
# isPitch                                       True           True
# matchup.batSide.code                             R              R
# matchup.pitchHand.code                           R              R
# pitchData.breaks.breakAngle                   25.2            7.2
# pitchData.breaks.breakLength                   4.8            7.2
# pitchData.breaks.breakY                         24             24
# pitchData.breaks.spinDirection                 210            145
# pitchData.breaks.spinRate                     2175           2047
# pitchData.coordinates.aX                     -10.2           2.34
# pitchData.coordinates.aY                     28.97          24.22
# pitchData.coordinates.aZ                    -16.52         -25.89
# pitchData.coordinates.pX                      0.68           0.68
# pitchData.coordinates.pZ                      2.37           0.77
# pitchData.coordinates.pfxX                   -5.65           1.45
# pitchData.coordinates.pfxZ                    8.67           3.89
# pitchData.coordinates.vX0                     8.32           5.73
# pitchData.coordinates.vY0                  -133.58         -125.9
# pitchData.coordinates.vZ0                    -6.46          -7.55
# pitchData.coordinates.x                      91.21          91.17
# pitchData.coordinates.x0                     -1.75          -1.81
# pitchData.coordinates.y                     174.95         218.02
# pitchData.coordinates.y0                        50             50
# pitchData.coordinates.z0                         6           5.89
# pitchData.endSpeed                            84.1           80.3
# pitchData.startSpeed                            92           86.7
# pitchNumber                                      4              5
#
#                                                364
# about.atBatIndex                                79
# count.balls                                      3
# count.outs                                       3
# count.strikes                                    3
# details.call.code                                S
# details.call.description         Strike - Swinging
# details.isBall                               False
# details.isStrike                              True
# details.type.code                               FF
# details.type.description        Four-Seam Fastball
# isPitch                                       True
# matchup.batSide.code                             R
# matchup.pitchHand.code                           R
# pitchData.breaks.breakAngle                   27.6
# pitchData.breaks.breakLength                   3.6
# pitchData.breaks.breakY                         24
# pitchData.breaks.spinDirection                 201
# pitchData.breaks.spinRate                     2094
# pitchData.coordinates.aX                     -8.77
# pitchData.coordinates.aY                     29.77
# pitchData.coordinates.aZ                    -12.85
# pitchData.coordinates.pX                     -0.07
# pitchData.coordinates.pZ                      3.09
# pitchData.coordinates.pfxX                   -4.83
# pitchData.coordinates.pfxZ                   10.63
# pitchData.coordinates.vX0                     6.54
# pitchData.coordinates.vY0                  -134.17
# pitchData.coordinates.vZ0                    -4.97
# pitchData.coordinates.x                     119.54
# pitchData.coordinates.x0                     -1.91
# pitchData.coordinates.y                     155.35
# pitchData.coordinates.y0                        50
# pitchData.coordinates.z0                      5.88
# pitchData.endSpeed                            84.1
# pitchData.startSpeed                          92.3
# pitchNumber                                      6

# %%
pitches_df.shape
# Out:
# (365, 36)

# %% [markdown]
# ---

# %% [markdown]
# ## Data Storage

# %% [markdown]
# Now that we have our data, let's store it in a PostgreSQL db on AWS so we don't have to keep rebuilding it.

# %% [markdown]
# ### 1. Use SQLAlchemy to create PSQL engine:

# %%
# dialect+driver://username:password@host:port/database

sql_alc_engine = create_engine('postgresql://dsaf:dsaf040119@flatiron-projects.\
cy8jwdkpepr0.us-west-2.rds.amazonaws.com/flatiron')

# %% [markdown]
# ### 2. Use `pandas.to_sql` to write the `pitches_df` dataframe to the PostgreSQL database, using the SQLAlchemy engine.

# %%
pitches_df.to_sql('pitches', sql_alc_engine)

# %% [markdown]
# ### 3. Check that the table was created.

# %%
# Setup PSQL connection
conn = psql.connect(
    database="flatiron",
    user="dsaf",
    password="dsaf040119",
    host="flatiron-projects.cy8jwdkpepr0.us-west-2.rds.amazonaws.com",
    port='5432'
)

# %%
# Set up query
query = """
    SELECT * FROM pitches;
"""

# %%
# Instantiate cursor
cur = conn.cursor()

# %%
# Execute the query
cur.execute(query)

# %%
# Check results
pitches_df_clone = pd.DataFrame(cur.fetchall())
pitches_df_clone.columns = [col.name for col in cur.description]

# %%
pitches_df_clone.head()
# Out:
#    index  about.atBatIndex  count.balls  count.outs  count.strikes  \
# 0      0                 0            3           1              3
# 1      1                 0            3           1              3
# 2      2                 0            3           1              3
# 3      3                 0            3           1              3
# 4      4                 0            3           1              3
#
#   details.call.code details.call.description details.isBall details.isStrike  \
# 0                 B            Ball - Called           True            False
# 1                 B            Ball - Called           True            False
# 2                 S        Strike - Swinging          False             True
# 3                 B            Ball - Called           True            False
# 4                 S        Strike - Swinging          False             True
#
#   details.type.code     ...      pitchData.coordinates.vY0  \
# 0                FF     ...                        -122.28
# 1                FT     ...                        -122.19
# 2                FT     ...                        -123.08
# 3                CH     ...                        -116.93
# 4                FT     ...                        -123.69
#
#    pitchData.coordinates.vZ0 pitchData.coordinates.x pitchData.coordinates.x0  \
# 0                      -6.67                   60.67                     2.80
# 1                      -3.37                   55.45                     2.74
# 2                      -5.83                  125.65                     2.60
# 3                      -5.93                   96.61                     2.48
# 4                      -3.51                  122.61                     2.55
#
#    pitchData.coordinates.y  pitchData.coordinates.y0  \
# 0                   196.16                      50.0
# 1                   170.30                      50.0
# 2                   193.72                      50.0
# 3                   206.66                      50.0
# 4                   167.13                      50.0
#
#    pitchData.coordinates.z0  pitchData.endSpeed  pitchData.startSpeed  \
# 0                      5.57                76.4                  84.3
# 1                      5.69                76.3                  84.2
# 2                      5.50                77.0                  84.9
# 3                      5.71                73.4                  80.8
# 4                      5.65                78.0                  85.2
#
#    pitchNumber
# 0          1.0
# 1          2.0
# 2          3.0
# 3          4.0
# 4          5.0
#
# [5 rows x 37 columns]

# %%
pitches_df.tail(7)
# Out:
#      about.atBatIndex  count.balls  count.outs  count.strikes  \
# 358                79            3           3              3
# 359                79            3           3              3
# 360                79            3           3              3
# 361                79            3           3              3
# 362                79            3           3              3
# 363                79            3           3              3
# 364                79            3           3              3
#
#     details.call.code details.call.description details.isBall  \
# 358               NaN                      NaN            NaN
# 359                 S        Strike - Swinging          False
# 360                 B            Ball - Called           True
# 361                 B            Ball - Called           True
# 362                 S        Strike - Swinging          False
# 363                 B            Ball - Called           True
# 364                 S        Strike - Swinging          False
#
#     details.isStrike details.type.code details.type.description     ...       \
# 358              NaN               NaN                      NaN     ...
# 359             True                SL                   Slider     ...
# 360            False                SL                   Slider     ...
# 361            False                SL                   Slider     ...
# 362             True                FF       Four-Seam Fastball     ...
# 363            False                SL                   Slider     ...
# 364             True                FF       Four-Seam Fastball     ...
#
#      pitchData.coordinates.vY0 pitchData.coordinates.vZ0  \
# 358                        NaN                       NaN
# 359                    -126.82                     -6.93
# 360                    -125.24                     -6.89
# 361                    -126.37                     -8.23
# 362                    -133.58                     -6.46
# 363                    -125.90                     -7.55
# 364                    -134.17                     -4.97
#
#     pitchData.coordinates.x  pitchData.coordinates.x0  \
# 358                     NaN                       NaN
# 359                  136.30                     -1.95
# 360                   44.66                     -1.80
# 361                  125.22                     -2.16
# 362                   91.21                     -1.75
# 363                   91.17                     -1.81
# 364                  119.54                     -1.91
#
#      pitchData.coordinates.y  pitchData.coordinates.y0  \
# 358                      NaN                       NaN
# 359                   193.04                      50.0
# 360                   209.73                      50.0
# 361                   219.16                      50.0
# 362                   174.95                      50.0
# 363                   218.02                      50.0
# 364                   155.35                      50.0
#
#      pitchData.coordinates.z0  pitchData.endSpeed  pitchData.startSpeed  \
# 358                       NaN                 NaN                   NaN
# 359                      6.14                80.4                  87.2
# 360                      6.01                79.7                  86.3
# 361                      5.96                80.2                  87.0
# 362                      6.00                84.1                  92.0
# 363                      5.89                80.3                  86.7
# 364                      5.88                84.1                  92.3
#
#      pitchNumber
# 358          NaN
# 359          1.0
# 360          2.0
# 361          3.0
# 362          4.0
# 363          5.0
# 364          6.0
#
# [7 rows x 36 columns]

# %%
pitches_df_clone.drop(['index'], axis=1, inplace=True)

# %%
pitches_df_clone.tail(7)
# Out:
#      about.atBatIndex  count.balls  count.outs  count.strikes  \
# 358                79            3           3              3
# 359                79            3           3              3
# 360                79            3           3              3
# 361                79            3           3              3
# 362                79            3           3              3
# 363                79            3           3              3
# 364                79            3           3              3
#
#     details.call.code details.call.description details.isBall  \
# 358               NaN                      NaN            NaN
# 359                 S        Strike - Swinging          False
# 360                 B            Ball - Called           True
# 361                 B            Ball - Called           True
# 362                 S        Strike - Swinging          False
# 363                 B            Ball - Called           True
# 364                 S        Strike - Swinging          False
#
#     details.isStrike details.type.code details.type.description     ...       \
# 358              NaN               NaN                      NaN     ...
# 359             True                SL                   Slider     ...
# 360            False                SL                   Slider     ...
# 361            False                SL                   Slider     ...
# 362             True                FF       Four-Seam Fastball     ...
# 363            False                SL                   Slider     ...
# 364             True                FF       Four-Seam Fastball     ...
#
#      pitchData.coordinates.vY0 pitchData.coordinates.vZ0  \
# 358                        NaN                       NaN
# 359                    -126.82                     -6.93
# 360                    -125.24                     -6.89
# 361                    -126.37                     -8.23
# 362                    -133.58                     -6.46
# 363                    -125.90                     -7.55
# 364                    -134.17                     -4.97
#
#     pitchData.coordinates.x  pitchData.coordinates.x0  \
# 358                     NaN                       NaN
# 359                  136.30                     -1.95
# 360                   44.66                     -1.80
# 361                  125.22                     -2.16
# 362                   91.21                     -1.75
# 363                   91.17                     -1.81
# 364                  119.54                     -1.91
#
#      pitchData.coordinates.y  pitchData.coordinates.y0  \
# 358                      NaN                       NaN
# 359                   193.04                      50.0
# 360                   209.73                      50.0
# 361                   219.16                      50.0
# 362                   174.95                      50.0
# 363                   218.02                      50.0
# 364                   155.35                      50.0
#
#      pitchData.coordinates.z0  pitchData.endSpeed  pitchData.startSpeed  \
# 358                       NaN                 NaN                   NaN
# 359                      6.14                80.4                  87.2
# 360                      6.01                79.7                  86.3
# 361                      5.96                80.2                  87.0
# 362                      6.00                84.1                  92.0
# 363                      5.89                80.3                  86.7
# 364                      5.88                84.1                  92.3
#
#      pitchNumber
# 358          NaN
# 359          1.0
# 360          2.0
# 361          3.0
# 362          4.0
# 363          5.0
# 364          6.0
#
# [7 rows x 36 columns]

# %%
pitches_df.equals(pitches_df)
# Out:
# True

# %%
pitches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 36 columns):
# about.atBatIndex                  365 non-null int64
# count.balls                       365 non-null int64
# count.outs                        365 non-null int64
# count.strikes                     365 non-null int64
# details.call.code                 318 non-null object
# details.call.description          318 non-null object
# details.isBall                    318 non-null object
# details.isStrike                  318 non-null object
# details.type.code                 318 non-null object
# details.type.description          318 non-null object
# isPitch                           365 non-null bool
# matchup.batSide.code              365 non-null object
# matchup.pitchHand.code            365 non-null object
# pitchData.breaks.breakAngle       318 non-null float64
# pitchData.breaks.breakLength      318 non-null float64
# pitchData.breaks.breakY           318 non-null float64
# pitchData.breaks.spinDirection    318 non-null float64
# pitchData.breaks.spinRate         317 non-null float64
# pitchData.coordinates.aX          318 non-null float64
# pitchData.coordinates.aY          318 non-null float64
# pitchData.coordinates.aZ          318 non-null float64
# pitchData.coordinates.pX          318 non-null float64
# pitchData.coordinates.pZ          318 non-null float64
# pitchData.coordinates.pfxX        318 non-null float64
# pitchData.coordinates.pfxZ        318 non-null float64
# pitchData.coordinates.vX0         318 non-null float64
# pitchData.coordinates.vY0         318 non-null float64
# pitchData.coordinates.vZ0         318 non-null float64
# pitchData.coordinates.x           316 non-null float64
# pitchData.coordinates.x0          318 non-null float64
# pitchData.coordinates.y           316 non-null float64
# pitchData.coordinates.y0          318 non-null float64
# pitchData.coordinates.z0          318 non-null float64
# pitchData.endSpeed                318 non-null float64
# pitchData.startSpeed              318 non-null float64
# pitchNumber                       318 non-null float64
# dtypes: bool(1), float64(23), int64(4), object(8)
# memory usage: 100.2+ KB

# %%
pitches_df_clone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 36 columns):
# about.atBatIndex                  365 non-null int64
# count.balls                       365 non-null int64
# count.outs                        365 non-null int64
# count.strikes                     365 non-null int64
# details.call.code                 318 non-null object
# details.call.description          318 non-null object
# details.isBall                    318 non-null object
# details.isStrike                  318 non-null object
# details.type.code                 318 non-null object
# details.type.description          318 non-null object
# isPitch                           365 non-null bool
# matchup.batSide.code              365 non-null object
# matchup.pitchHand.code            365 non-null object
# pitchData.breaks.breakAngle       318 non-null float64
# pitchData.breaks.breakLength      318 non-null float64
# pitchData.breaks.breakY           318 non-null float64
# pitchData.breaks.spinDirection    318 non-null float64
# pitchData.breaks.spinRate         317 non-null float64
# pitchData.coordinates.aX          318 non-null float64
# pitchData.coordinates.aY          318 non-null float64
# pitchData.coordinates.aZ          318 non-null float64
# pitchData.coordinates.pX          318 non-null float64
# pitchData.coordinates.pZ          318 non-null float64
# pitchData.coordinates.pfxX        318 non-null float64
# pitchData.coordinates.pfxZ        318 non-null float64
# pitchData.coordinates.vX0         318 non-null float64
# pitchData.coordinates.vY0         318 non-null float64
# pitchData.coordinates.vZ0         318 non-null float64
# pitchData.coordinates.x           316 non-null float64
# pitchData.coordinates.x0          318 non-null float64
# pitchData.coordinates.y           316 non-null float64
# pitchData.coordinates.y0          318 non-null float64
# pitchData.coordinates.z0          318 non-null float64
# pitchData.endSpeed                318 non-null float64
# pitchData.startSpeed              318 non-null float64
# pitchNumber                       318 non-null float64
# dtypes: bool(1), float64(23), int64(4), object(8)
# memory usage: 100.2+ KB

# %%
pitches_df_clone.shape
# Out:
# (365, 36)

# %% [markdown]
# Ah, it seems that `NaN` got transformed to None in the migration to PSQL and come back as such.

# %%
pitches_df.loc[pitches_df['details.call.code'].isna() ].shape
# Out:
# (47, 36)

# %%
# Let's try to find the Nones
pitches_df_clone.loc[pitches_df_clone['details.call.code'].isna() ].shape
# Out:
# (47, 36)

# %%
pitches_df['details.call.code'] == pitches_df_clone['details.call.code']
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 335     True
# 336     True
# 337     True
# 338     True
# 339     True
# 340     True
# 341     True
# 342     True
# 343    False
# 344     True
# 345     True
# 346     True
# 347     True
# 348    False
# 349     True
# 350     True
# 351     True
# 352     True
# 353     True
# 354     True
# 355     True
# 356     True
# 357     True
# 358    False
# 359     True
# 360     True
# 361     True
# 362     True
# 363     True
# 364     True
# Name: details.call.code, Length: 365, dtype: bool

# %%
pitches_df_clone['details.call.code'].value_counts()
# Out:
# S    142
# B    123
# X     53
# Name: details.call.code, dtype: int64

# %%
142+123+53
# Out:
# 318

# %%
import numpy as np

# %%
pitches_df_clone.replace([None], np.nan, inplace=True)

# %%
pitches_df_clone.tail(7)
# Out:
#      about.atBatIndex  count.balls  count.outs  count.strikes  \
# 358                79            3           3              3
# 359                79            3           3              3
# 360                79            3           3              3
# 361                79            3           3              3
# 362                79            3           3              3
# 363                79            3           3              3
# 364                79            3           3              3
#
#     details.call.code details.call.description details.isBall  \
# 358               NaN                      NaN            NaN
# 359                 S        Strike - Swinging          False
# 360                 B            Ball - Called           True
# 361                 B            Ball - Called           True
# 362                 S        Strike - Swinging          False
# 363                 B            Ball - Called           True
# 364                 S        Strike - Swinging          False
#
#     details.isStrike details.type.code details.type.description     ...       \
# 358              NaN               NaN                      NaN     ...
# 359             True                SL                   Slider     ...
# 360            False                SL                   Slider     ...
# 361            False                SL                   Slider     ...
# 362             True                FF       Four-Seam Fastball     ...
# 363            False                SL                   Slider     ...
# 364             True                FF       Four-Seam Fastball     ...
#
#      pitchData.coordinates.vY0 pitchData.coordinates.vZ0  \
# 358                        NaN                       NaN
# 359                    -126.82                     -6.93
# 360                    -125.24                     -6.89
# 361                    -126.37                     -8.23
# 362                    -133.58                     -6.46
# 363                    -125.90                     -7.55
# 364                    -134.17                     -4.97
#
#     pitchData.coordinates.x  pitchData.coordinates.x0  \
# 358                     NaN                       NaN
# 359                  136.30                     -1.95
# 360                   44.66                     -1.80
# 361                  125.22                     -2.16
# 362                   91.21                     -1.75
# 363                   91.17                     -1.81
# 364                  119.54                     -1.91
#
#      pitchData.coordinates.y  pitchData.coordinates.y0  \
# 358                      NaN                       NaN
# 359                   193.04                      50.0
# 360                   209.73                      50.0
# 361                   219.16                      50.0
# 362                   174.95                      50.0
# 363                   218.02                      50.0
# 364                   155.35                      50.0
#
#      pitchData.coordinates.z0  pitchData.endSpeed  pitchData.startSpeed  \
# 358                       NaN                 NaN                   NaN
# 359                      6.14                80.4                  87.2
# 360                      6.01                79.7                  86.3
# 361                      5.96                80.2                  87.0
# 362                      6.00                84.1                  92.0
# 363                      5.89                80.3                  86.7
# 364                      5.88                84.1                  92.3
#
#      pitchNumber
# 358          NaN
# 359          1.0
# 360          2.0
# 361          3.0
# 362          4.0
# 363          5.0
# 364          6.0
#
# [7 rows x 36 columns]

# %%
pitches_df_clone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 36 columns):
# about.atBatIndex                  365 non-null int64
# count.balls                       365 non-null int64
# count.outs                        365 non-null int64
# count.strikes                     365 non-null int64
# details.call.code                 318 non-null object
# details.call.description          318 non-null object
# details.isBall                    318 non-null object
# details.isStrike                  318 non-null object
# details.type.code                 318 non-null object
# details.type.description          318 non-null object
# isPitch                           365 non-null bool
# matchup.batSide.code              365 non-null object
# matchup.pitchHand.code            365 non-null object
# pitchData.breaks.breakAngle       318 non-null float64
# pitchData.breaks.breakLength      318 non-null float64
# pitchData.breaks.breakY           318 non-null float64
# pitchData.breaks.spinDirection    318 non-null float64
# pitchData.breaks.spinRate         317 non-null float64
# pitchData.coordinates.aX          318 non-null float64
# pitchData.coordinates.aY          318 non-null float64
# pitchData.coordinates.aZ          318 non-null float64
# pitchData.coordinates.pX          318 non-null float64
# pitchData.coordinates.pZ          318 non-null float64
# pitchData.coordinates.pfxX        318 non-null float64
# pitchData.coordinates.pfxZ        318 non-null float64
# pitchData.coordinates.vX0         318 non-null float64
# pitchData.coordinates.vY0         318 non-null float64
# pitchData.coordinates.vZ0         318 non-null float64
# pitchData.coordinates.x           316 non-null float64
# pitchData.coordinates.x0          318 non-null float64
# pitchData.coordinates.y           316 non-null float64
# pitchData.coordinates.y0          318 non-null float64
# pitchData.coordinates.z0          318 non-null float64
# pitchData.endSpeed                318 non-null float64
# pitchData.startSpeed              318 non-null float64
# pitchNumber                       318 non-null float64
# dtypes: bool(1), float64(23), int64(4), object(8)
# memory usage: 100.2+ KB

# %%
pitches_df == pitches_df_clone
# Out:
#      about.atBatIndex  count.balls  count.outs  count.strikes  \
# 0                True         True        True           True
# 1                True         True        True           True
# 2                True         True        True           True
# 3                True         True        True           True
# 4                True         True        True           True
# 5                True         True        True           True
# 6                True         True        True           True
# 7                True         True        True           True
# 8                True         True        True           True
# 9                True         True        True           True
# 10               True         True        True           True
# 11               True         True        True           True
# 12               True         True        True           True
# 13               True         True        True           True
# 14               True         True        True           True
# 15               True         True        True           True
# 16               True         True        True           True
# 17               True         True        True           True
# 18               True         True        True           True
# 19               True         True        True           True
# 20               True         True        True           True
# 21               True         True        True           True
# 22               True         True        True           True
# 23               True         True        True           True
# 24               True         True        True           True
# 25               True         True        True           True
# 26               True         True        True           True
# 27               True         True        True           True
# 28               True         True        True           True
# 29               True         True        True           True
# ..                ...          ...         ...            ...
# 335              True         True        True           True
# 336              True         True        True           True
# 337              True         True        True           True
# 338              True         True        True           True
# 339              True         True        True           True
# 340              True         True        True           True
# 341              True         True        True           True
# 342              True         True        True           True
# 343              True         True        True           True
# 344              True         True        True           True
# 345              True         True        True           True
# 346              True         True        True           True
# 347              True         True        True           True
# 348              True         True        True           True
# 349              True         True        True           True
# 350              True         True        True           True
# 351              True         True        True           True
# 352              True         True        True           True
# 353              True         True        True           True
# 354              True         True        True           True
# 355              True         True        True           True
# 356              True         True        True           True
# 357              True         True        True           True
# 358              True         True        True           True
# 359              True         True        True           True
# 360              True         True        True           True
# 361              True         True        True           True
# 362              True         True        True           True
# 363              True         True        True           True
# 364              True         True        True           True
#
#      details.call.code  details.call.description  details.isBall  \
# 0                 True                      True            True
# 1                 True                      True            True
# 2                 True                      True            True
# 3                 True                      True            True
# 4                 True                      True            True
# 5                 True                      True            True
# 6                 True                      True            True
# 7                 True                      True            True
# 8                 True                      True            True
# 9                 True                      True            True
# 10                True                      True            True
# 11                True                      True            True
# 12                True                      True            True
# 13                True                      True            True
# 14                True                      True            True
# 15                True                      True            True
# 16                True                      True            True
# 17                True                      True            True
# 18                True                      True            True
# 19                True                      True            True
# 20                True                      True            True
# 21                True                      True            True
# 22                True                      True            True
# 23                True                      True            True
# 24                True                      True            True
# 25                True                      True            True
# 26                True                      True            True
# 27                True                      True            True
# 28                True                      True            True
# 29                True                      True            True
# ..                 ...                       ...             ...
# 335               True                      True            True
# 336               True                      True            True
# 337               True                      True            True
# 338               True                      True            True
# 339               True                      True            True
# 340               True                      True            True
# 341               True                      True            True
# 342               True                      True            True
# 343              False                     False           False
# 344               True                      True            True
# 345               True                      True            True
# 346               True                      True            True
# 347               True                      True            True
# 348              False                     False           False
# 349               True                      True            True
# 350               True                      True            True
# 351               True                      True            True
# 352               True                      True            True
# 353               True                      True            True
# 354               True                      True            True
# 355               True                      True            True
# 356               True                      True            True
# 357               True                      True            True
# 358              False                     False           False
# 359               True                      True            True
# 360               True                      True            True
# 361               True                      True            True
# 362               True                      True            True
# 363               True                      True            True
# 364               True                      True            True
#
#      details.isStrike  details.type.code  details.type.description  \
# 0                True               True                      True
# 1                True               True                      True
# 2                True               True                      True
# 3                True               True                      True
# 4                True               True                      True
# 5                True               True                      True
# 6                True               True                      True
# 7                True               True                      True
# 8                True               True                      True
# 9                True               True                      True
# 10               True               True                      True
# 11               True               True                      True
# 12               True               True                      True
# 13               True               True                      True
# 14               True               True                      True
# 15               True               True                      True
# 16               True               True                      True
# 17               True               True                      True
# 18               True               True                      True
# 19               True               True                      True
# 20               True               True                      True
# 21               True               True                      True
# 22               True               True                      True
# 23               True               True                      True
# 24               True               True                      True
# 25               True               True                      True
# 26               True               True                      True
# 27               True               True                      True
# 28               True               True                      True
# 29               True               True                      True
# ..                ...                ...                       ...
# 335              True               True                      True
# 336              True               True                      True
# 337              True               True                      True
# 338              True               True                      True
# 339              True               True                      True
# 340              True               True                      True
# 341              True               True                      True
# 342              True               True                      True
# 343             False              False                     False
# 344              True               True                      True
# 345              True               True                      True
# 346              True               True                      True
# 347              True               True                      True
# 348             False              False                     False
# 349              True               True                      True
# 350              True               True                      True
# 351              True               True                      True
# 352              True               True                      True
# 353              True               True                      True
# 354              True               True                      True
# 355              True               True                      True
# 356              True               True                      True
# 357              True               True                      True
# 358             False              False                     False
# 359              True               True                      True
# 360              True               True                      True
# 361              True               True                      True
# 362              True               True                      True
# 363              True               True                      True
# 364              True               True                      True
#
#         ...       pitchData.coordinates.vY0  pitchData.coordinates.vZ0  \
# 0       ...                            True                       True
# 1       ...                            True                       True
# 2       ...                            True                       True
# 3       ...                            True                       True
# 4       ...                            True                       True
# 5       ...                            True                       True
# 6       ...                            True                       True
# 7       ...                            True                       True
# 8       ...                            True                       True
# 9       ...                            True                       True
# 10      ...                            True                       True
# 11      ...                            True                       True
# 12      ...                            True                       True
# 13      ...                            True                       True
# 14      ...                            True                       True
# 15      ...                            True                       True
# 16      ...                            True                       True
# 17      ...                            True                       True
# 18      ...                            True                       True
# 19      ...                            True                       True
# 20      ...                            True                       True
# 21      ...                            True                       True
# 22      ...                            True                       True
# 23      ...                            True                       True
# 24      ...                            True                       True
# 25      ...                            True                       True
# 26      ...                            True                       True
# 27      ...                            True                       True
# 28      ...                            True                       True
# 29      ...                            True                       True
# ..      ...                             ...                        ...
# 335     ...                            True                       True
# 336     ...                            True                       True
# 337     ...                            True                       True
# 338     ...                            True                       True
# 339     ...                            True                       True
# 340     ...                            True                       True
# 341     ...                            True                       True
# 342     ...                            True                       True
# 343     ...                           False                      False
# 344     ...                            True                       True
# 345     ...                            True                       True
# 346     ...                            True                       True
# 347     ...                            True                       True
# 348     ...                           False                      False
# 349     ...                            True                       True
# 350     ...                            True                       True
# 351     ...                            True                       True
# 352     ...                            True                       True
# 353     ...                            True                       True
# 354     ...                            True                       True
# 355     ...                            True                       True
# 356     ...                            True                       True
# 357     ...                            True                       True
# 358     ...                           False                      False
# 359     ...                            True                       True
# 360     ...                            True                       True
# 361     ...                            True                       True
# 362     ...                            True                       True
# 363     ...                            True                       True
# 364     ...                            True                       True
#
#      pitchData.coordinates.x  pitchData.coordinates.x0  \
# 0                       True                      True
# 1                       True                      True
# 2                       True                      True
# 3                       True                      True
# 4                       True                      True
# 5                       True                      True
# 6                       True                      True
# 7                       True                      True
# 8                       True                      True
# 9                       True                      True
# 10                      True                      True
# 11                      True                      True
# 12                      True                      True
# 13                      True                      True
# 14                      True                      True
# 15                      True                      True
# 16                      True                      True
# 17                      True                      True
# 18                      True                      True
# 19                      True                      True
# 20                      True                      True
# 21                      True                      True
# 22                      True                      True
# 23                      True                      True
# 24                      True                      True
# 25                      True                      True
# 26                      True                      True
# 27                      True                      True
# 28                      True                      True
# 29                      True                      True
# ..                       ...                       ...
# 335                     True                      True
# 336                     True                      True
# 337                     True                      True
# 338                     True                      True
# 339                     True                      True
# 340                     True                      True
# 341                     True                      True
# 342                     True                      True
# 343                    False                     False
# 344                     True                      True
# 345                     True                      True
# 346                     True                      True
# 347                     True                      True
# 348                    False                     False
# 349                     True                      True
# 350                     True                      True
# 351                     True                      True
# 352                     True                      True
# 353                     True                      True
# 354                     True                      True
# 355                     True                      True
# 356                     True                      True
# 357                     True                      True
# 358                    False                     False
# 359                     True                      True
# 360                     True                      True
# 361                     True                      True
# 362                     True                      True
# 363                     True                      True
# 364                     True                      True
#
#      pitchData.coordinates.y  pitchData.coordinates.y0  \
# 0                       True                      True
# 1                       True                      True
# 2                       True                      True
# 3                       True                      True
# 4                       True                      True
# 5                       True                      True
# 6                       True                      True
# 7                       True                      True
# 8                       True                      True
# 9                       True                      True
# 10                      True                      True
# 11                      True                      True
# 12                      True                      True
# 13                      True                      True
# 14                      True                      True
# 15                      True                      True
# 16                      True                      True
# 17                      True                      True
# 18                      True                      True
# 19                      True                      True
# 20                      True                      True
# 21                      True                      True
# 22                      True                      True
# 23                      True                      True
# 24                      True                      True
# 25                      True                      True
# 26                      True                      True
# 27                      True                      True
# 28                      True                      True
# 29                      True                      True
# ..                       ...                       ...
# 335                     True                      True
# 336                     True                      True
# 337                     True                      True
# 338                     True                      True
# 339                     True                      True
# 340                     True                      True
# 341                     True                      True
# 342                     True                      True
# 343                    False                     False
# 344                     True                      True
# 345                     True                      True
# 346                     True                      True
# 347                     True                      True
# 348                    False                     False
# 349                     True                      True
# 350                     True                      True
# 351                     True                      True
# 352                     True                      True
# 353                     True                      True
# 354                     True                      True
# 355                     True                      True
# 356                     True                      True
# 357                     True                      True
# 358                    False                     False
# 359                     True                      True
# 360                     True                      True
# 361                     True                      True
# 362                     True                      True
# 363                     True                      True
# 364                     True                      True
#
#      pitchData.coordinates.z0  pitchData.endSpeed  pitchData.startSpeed  \
# 0                        True                True                  True
# 1                        True                True                  True
# 2                        True                True                  True
# 3                        True                True                  True
# 4                        True                True                  True
# 5                        True                True                  True
# 6                        True                True                  True
# 7                        True                True                  True
# 8                        True                True                  True
# 9                        True                True                  True
# 10                       True                True                  True
# 11                       True                True                  True
# 12                       True                True                  True
# 13                       True                True                  True
# 14                       True                True                  True
# 15                       True                True                  True
# 16                       True                True                  True
# 17                       True                True                  True
# 18                       True                True                  True
# 19                       True                True                  True
# 20                       True                True                  True
# 21                       True                True                  True
# 22                       True                True                  True
# 23                       True                True                  True
# 24                       True                True                  True
# 25                       True                True                  True
# 26                       True                True                  True
# 27                       True                True                  True
# 28                       True                True                  True
# 29                       True                True                  True
# ..                        ...                 ...                   ...
# 335                      True                True                  True
# 336                      True                True                  True
# 337                      True                True                  True
# 338                      True                True                  True
# 339                      True                True                  True
# 340                      True                True                  True
# 341                      True                True                  True
# 342                      True                True                  True
# 343                     False               False                 False
# 344                      True                True                  True
# 345                      True                True                  True
# 346                      True                True                  True
# 347                      True                True                  True
# 348                     False               False                 False
# 349                      True                True                  True
# 350                      True                True                  True
# 351                      True                True                  True
# 352                      True                True                  True
# 353                      True                True                  True
# 354                      True                True                  True
# 355                      True                True                  True
# 356                      True                True                  True
# 357                      True                True                  True
# 358                     False               False                 False
# 359                      True                True                  True
# 360                      True                True                  True
# 361                      True                True                  True
# 362                      True                True                  True
# 363                      True                True                  True
# 364                      True                True                  True
#
#      pitchNumber
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# 5           True
# 6           True
# 7           True
# 8           True
# 9           True
# 10          True
# 11          True
# 12          True
# 13          True
# 14          True
# 15          True
# 16          True
# 17          True
# 18          True
# 19          True
# 20          True
# 21          True
# 22          True
# 23          True
# 24          True
# 25          True
# 26          True
# 27          True
# 28          True
# 29          True
# ..           ...
# 335         True
# 336         True
# 337         True
# 338         True
# 339         True
# 340         True
# 341         True
# 342         True
# 343        False
# 344         True
# 345         True
# 346         True
# 347         True
# 348        False
# 349         True
# 350         True
# 351         True
# 352         True
# 353         True
# 354         True
# 355         True
# 356         True
# 357         True
# 358        False
# 359         True
# 360         True
# 361         True
# 362         True
# 363         True
# 364         True
#
# [365 rows x 36 columns]

# %%
pitches_df.iloc[358,4:5]
# Out:
# pandas.core.series.Series

# %%
pitches_df.iloc[358,4:5]
# Out:
# details.call.code    NaN
# Name: 358, dtype: object

# %%
pitches_df.iat[358,4]
# Out:
# nan

# %%
pitches_df_clone.iat[358,4]
# Out:
# nan

# %%
pitches_df.iat[358,4] ==pitches_df_clone.iat[358,4]
# Out:
# False

# %%
np.sum(pitches_df.iloc[:,0]==pitches_df_clone.iloc[:,0])
# Out:
# 338

# %%
pitches_df.iloc[:,0].equals(pitches_df_clone.iloc[:,0])
# Out:
# False

# %%
pitches_df.loc[pitches_df.iloc[:,0]!=pitches_df_clone.iloc[:,0],]
# Out:
#      about.atBatIndex  count.balls  count.outs  count.strikes  \
# 58                 11            0           3              1
# 59                 12            1           0              1
# 62                 13            2           1              1
# 66                 14            0           2              0
# 67                 15            0           3              1
# 69                 16            3           1              2
# 75                 17            2           2              2
# 80                 18            1           3              3
# 85                 19            4           0              0
# 89                 20            1           1              3
# 93                 21            1           2              3
# 102                22            2           3              2
# 108                23            1           1              1
# 111                24            4           1              0
# 115                25            2           1              1
# 119                26            2           2              3
# 126                27            2           3              3
# 133                28            1           1              2
# 137                29            2           2              2
# 142                30            0           3              2
# 145                31            1           0              1
# 147                32            1           1              0
# 150                33            2           2              3
# 156                34            1           3              1
# 159                35            3           1              2
# 166                36            2           1              1
# 170                37            4           1              2
#
#     details.call.code details.call.description details.isBall  \
# 58                  X   Hit Into Play - Out(s)          False
# 59                  S        Strike - Swinging          False
# 62                  S        Strike - Swinging          False
# 66                  X   Hit Into Play - Out(s)          False
# 67                  S        Strike - Swinging          False
# 69                  S        Strike - Swinging          False
# 75                  B            Ball - Called           True
# 80                  S        Strike - Swinging          False
# 85                  B            Ball - Called           True
# 89                  B            Ball - Called           True
# 93                  S        Strike - Swinging          False
# 102                 S        Strike - Swinging          False
# 108                 B            Ball - Called           True
# 111                 B            Ball - Called           True
# 115                 S        Strike - Swinging          False
# 119                 S        Strike - Swinging          False
# 126                 S        Strike - Swinging          False
# 133                 S        Strike - Swinging          False
# 137                 B            Ball - Called           True
# 142                 S        Strike - Swinging          False
# 145                 S        Strike - Swinging          False
# 147                 B            Ball - Called           True
# 150                 B            Ball - Called           True
# 156                 S        Strike - Swinging          False
# 159                 B            Ball - Called           True
# 166                 B            Ball - Called           True
# 170                 S        Strike - Swinging          False
#
#     details.isStrike details.type.code details.type.description     ...       \
# 58             False                FF       Four-Seam Fastball     ...
# 59              True                FF       Four-Seam Fastball     ...
# 62              True                FF       Four-Seam Fastball     ...
# 66             False                CH                 Changeup     ...
# 67              True                FT        Two-Seam Fastball     ...
# 69              True                FF       Four-Seam Fastball     ...
# 75             False                FF       Four-Seam Fastball     ...
# 80              True                FF       Four-Seam Fastball     ...
# 85             False                CH                 Changeup     ...
# 89             False                FT        Two-Seam Fastball     ...
# 93              True                CH                 Changeup     ...
# 102             True                FT        Two-Seam Fastball     ...
# 108            False                SL                   Slider     ...
# 111            False                FF       Four-Seam Fastball     ...
# 115             True                FF       Four-Seam Fastball     ...
# 119             True                FT        Two-Seam Fastball     ...
# 126             True                FF       Four-Seam Fastball     ...
# 133             True                FT        Two-Seam Fastball     ...
# 137            False                KC            Knuckle Curve     ...
# 142             True                FF       Four-Seam Fastball     ...
# 145             True                FF       Four-Seam Fastball     ...
# 147            False                FF       Four-Seam Fastball     ...
# 150            False                FF       Four-Seam Fastball     ...
# 156             True                FF       Four-Seam Fastball     ...
# 159            False                CH                 Changeup     ...
# 166            False                CH                 Changeup     ...
# 170             True                CH                 Changeup     ...
#
#      pitchData.coordinates.vY0 pitchData.coordinates.vZ0  \
# 58                     -136.43                     -6.18
# 59                     -120.41                     -3.98
# 62                     -121.04                     -4.28
# 66                     -115.02                     -0.80
# 67                     -123.86                     -3.23
# 69                     -136.35                     -6.95
# 75                     -138.93                    -11.05
# 80                     -137.04                     -4.53
# 85                     -114.12                     -1.80
# 89                     -124.18                     -5.38
# 93                     -115.46                     -2.81
# 102                    -124.77                     -3.39
# 108                    -123.10                      0.83
# 111                    -136.18                     -8.72
# 115                    -137.40                     -5.92
# 119                    -135.13                     -6.46
# 126                    -139.74                     -5.39
# 133                    -120.20                     -2.93
# 137                    -104.79                      3.78
# 142                    -124.09                     -4.53
# 145                    -137.28                     -5.31
# 147                    -138.56                     -5.19
# 150                    -138.71                     -7.89
# 156                    -138.66                     -8.13
# 159                    -112.89                     -0.39
# 166                    -116.55                     -1.08
# 170                    -117.44                     -3.35
#
#     pitchData.coordinates.x  pitchData.coordinates.x0  \
# 58                   112.44                     -2.10
# 59                    76.02                      2.82
# 62                   124.60                      2.62
# 66                    66.25                      2.74
# 67                   131.82                      2.67
# 69                   115.99                     -2.11
# 75                   141.69                     -2.19
# 80                   135.80                     -2.38
# 85                    17.52                      2.88
# 89                   172.68                      2.63
# 93                    84.98                      2.71
# 102                  101.50                      2.92
# 108                  170.12                     -2.46
# 111                   78.41                     -2.07
# 115                  134.36                     -2.33
# 119                  164.16                     -2.51
# 126                  106.58                     -2.12
# 133                  108.01                      2.95
# 137                   94.92                      2.93
# 142                   94.81                      2.92
# 145                  125.29                     -2.12
# 147                  174.67                     -2.34
# 150                  160.19                     -2.24
# 156                  128.60                     -2.02
# 159                   44.53                      2.73
# 166                   49.42                      2.68
# 170                   94.45                      2.61
#
#      pitchData.coordinates.y  pitchData.coordinates.y0  \
# 58                    172.61                      50.0
# 59                    170.87                      50.0
# 62                    175.33                      50.0
# 66                    154.49                      50.0
# 67                    170.74                      50.0
# 69                    177.94                      50.0
# 75                    219.42                      50.0
# 80                    152.88                      50.0
# 85                    166.86                      50.0
# 89                    191.89                      50.0
# 93                    180.12                      50.0
# 102                   178.42                      50.0
# 108                   129.74                      50.0
# 111                   196.67                      50.0
# 115                   163.46                      50.0
# 119                   198.44                      50.0
# 126                   155.20                      50.0
# 133                   180.92                      50.0
# 137                   143.40                      50.0
# 142                   177.18                      50.0
# 145                   158.70                      50.0
# 147                   154.23                      50.0
# 150                   182.86                      50.0
# 156                   187.18                      50.0
# 159                   156.44                      50.0
# 166                   157.51                      50.0
# 170                   194.96                      50.0
#
#      pitchData.coordinates.z0  pitchData.endSpeed  pitchData.startSpeed  \
# 58                       5.73                86.2                  93.8
# 59                       5.66                75.4                  82.9
# 62                       5.60                75.8                  83.5
# 66                       5.85                71.8                  79.2
# 67                       5.58                78.0                  85.5
# 69                       5.81                85.3                  93.9
# 75                       5.49                87.7                  95.7
# 80                       5.71                85.7                  94.3
# 85                       5.82                71.8                  78.5
# 89                       5.40                77.9                  85.9
# 93                       5.71                72.2                  79.6
# 102                      5.47                77.8                  86.0
# 108                      6.12                77.5                  84.6
# 111                      5.63                85.7                  93.9
# 115                      5.73                85.2                  94.6
# 119                      5.51                85.6                  92.9
# 126                      5.74                87.1                  96.2
# 133                      5.60                75.9                  82.9
# 137                      6.10                66.2                  72.2
# 142                      5.48                77.6                  85.6
# 145                      5.82                86.4                  94.3
# 147                      5.82                87.2                  95.1
# 150                      5.64                87.2                  95.4
# 156                      5.65                86.8                  95.4
# 159                      5.91                70.8                  77.7
# 166                      5.81                73.1                  80.3
# 170                      5.68                73.8                  81.0
#
#      pitchNumber
# 58           2.0
# 59           1.0
# 62           1.0
# 66           1.0
# 67           1.0
# 69           1.0
# 75           1.0
# 80           1.0
# 85           1.0
# 89           1.0
# 93           1.0
# 102          1.0
# 108          1.0
# 111          1.0
# 115          1.0
# 119          1.0
# 126          1.0
# 133          1.0
# 137          1.0
# 142          1.0
# 145          1.0
# 147          1.0
# 150          1.0
# 156          1.0
# 159          1.0
# 166          1.0
# 170          1.0
#
# [27 rows x 36 columns]

# %%
pitches_df.iloc[58,:]
# Out:
# about.atBatIndex                                      11
# count.balls                                            0
# count.outs                                             3
# count.strikes                                          1
# details.call.code                                      X
# details.call.description          Hit Into Play - Out(s)
# details.isBall                                     False
# details.isStrike                                   False
# details.type.code                                     FF
# details.type.description              Four-Seam Fastball
# isPitch                                             True
# matchup.batSide.code                                   R
# matchup.pitchHand.code                                 R
# pitchData.breaks.breakAngle                          3.6
# pitchData.breaks.breakLength                         3.6
# pitchData.breaks.breakY                               24
# pitchData.breaks.spinDirection                       182
# pitchData.breaks.spinRate                           2372
# pitchData.coordinates.aX                           -2.15
# pitchData.coordinates.aY                            28.8
# pitchData.coordinates.aZ                          -14.37
# pitchData.coordinates.pX                            0.12
# pitchData.coordinates.pZ                            2.45
# pitchData.coordinates.pfxX                         -1.14
# pitchData.coordinates.pfxZ                          9.41
# pitchData.coordinates.vX0                           6.39
# pitchData.coordinates.vY0                        -136.43
# pitchData.coordinates.vZ0                          -6.18
# pitchData.coordinates.x                           112.44
# pitchData.coordinates.x0                            -2.1
# pitchData.coordinates.y                           172.61
# pitchData.coordinates.y0                              50
# pitchData.coordinates.z0                            5.73
# pitchData.endSpeed                                  86.2
# pitchData.startSpeed                                93.8
# pitchNumber                                            2
# Name: 58, dtype: object

# %%
pitches_df_clone.iloc[58,:]
# Out:
# about.atBatIndex                     37
# count.balls                           4
# count.outs                            1
# count.strikes                         2
# details.call.code                   NaN
# details.call.description            NaN
# details.isBall                      NaN
# details.isStrike                    NaN
# details.type.code                   NaN
# details.type.description            NaN
# isPitch                           False
# matchup.batSide.code                  R
# matchup.pitchHand.code                L
# pitchData.breaks.breakAngle         NaN
# pitchData.breaks.breakLength        NaN
# pitchData.breaks.breakY             NaN
# pitchData.breaks.spinDirection      NaN
# pitchData.breaks.spinRate           NaN
# pitchData.coordinates.aX            NaN
# pitchData.coordinates.aY            NaN
# pitchData.coordinates.aZ            NaN
# pitchData.coordinates.pX            NaN
# pitchData.coordinates.pZ            NaN
# pitchData.coordinates.pfxX          NaN
# pitchData.coordinates.pfxZ          NaN
# pitchData.coordinates.vX0           NaN
# pitchData.coordinates.vY0           NaN
# pitchData.coordinates.vZ0           NaN
# pitchData.coordinates.x             NaN
# pitchData.coordinates.x0            NaN
# pitchData.coordinates.y             NaN
# pitchData.coordinates.y0            NaN
# pitchData.coordinates.z0            NaN
# pitchData.endSpeed                  NaN
# pitchData.startSpeed                NaN
# pitchNumber                         NaN
# Name: 58, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# # Notes / To Dos

# %% [markdown]
# ### 1. Need to incorporate work to create list of desired games. Likely will require looping through list.

# %% [markdown]
# ### 2. Should this data be written out to a database, e.g. SQL or NoSQL?

# %% [markdown]
# ### 3. Other data to join? Team Characteristics? Player characteristics? RISP??
