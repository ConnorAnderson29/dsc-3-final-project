# %% [markdown]
# # Getting Pitch-level Data
# The goal is to obtain data related to a single pitch in an MLB game, given our decided parameters. For example, "the 2nd pitch of the 3rd at-bat of the bottom of the first inning" (to demonstrate the granularity).

# %% [markdown]
# ---

# %% [markdown]
# ## Libraries

# %%
#DATA WRANGLING
import pandas as pd # Dataframes
from pandas.io.json import json_normalize # JSON wrangler
import statsapi # Python wrapper MLB data API
#DATA STORAGE
#from sqlalchemy import create_engine # SQL helper
import psycopg2 as psql #PostgreSQL DBs
#DATA MANIPULATION AND MODELLING
import numpy as np
np.random.seed(0)
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, GradientBoostingClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn_pandas import DataFrameMapper, FunctionTransformer, gen_features, pipeline
from sklearn_pandas.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import seaborn as sns
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score
from sklearn.preprocessing import LabelBinarizer
import pitch_functions
import xgboost as xgb
import os

# %%
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %% [markdown]
# ---

# %% [markdown]
# ## Data Retrieval
#
# In order to retrieval publicly available data from the Major League Baseball Stats API, we will use a module called `statsapi`.

# %% [markdown]
# ### 1. Determine list of games

# %%
schedule = statsapi.schedule(start_date="04/01/2018", end_date="09/30/2018", team=136)
full = json_normalize(schedule)
list_game_pks = full['game_id']

# %%
gamepks = list(list_game_pks.unique())
len(gamepks)
# Out:
# 160

# %% [markdown]
# ### 2. Retrieve play-by-play data for game(s).

# %% [markdown]
# for index, row in play_ev.iterrows(): #Just using first 2 rows for testing
#
#         # saw playEvents is a nested list, so json_normalize it
#         play_events_df = json_normalize(row['playEvents'])
# play_events_df.columns

# %%
# Get one game from API
list_for_new_df = []
#gamepks = [566389]
for game in gamepks[:2]:
    #print(game)
    i = 1
    
    curr_game = statsapi.get('game_playByPlay',{'gamePk':game})

    ### 3. Extract play-by-play data and store into dataframe.

    # Only care about the allPlays key 
    curr_plays = curr_game.get('allPlays')

    # Coerce all plays into a df
    curr_plays_df = json_normalize(curr_plays)

    ###################################
    # Build target table
    ###################################


    # Data from allPlays
    ap_sel_cols = ['about.atBatIndex', 'about.halfInning', 'about.inning', 'result.awayScore', 'result.homeScore'
                   ,'matchup.splits.menOnBase', 'matchup.batSide.code', 'matchup.pitchHand.code', 'count.balls'
              ,'count.strikes', 'count.outs']

    # Data from playEvents
    plev_sel_cols = ['details.type.code', 'details.type.description',  
             'isPitch', 'pitchNumber'
            
           ]

    # Now go through each row. If there is nested list, json_normalize it
    #for index, row in test_df.head(2).iterrows(): #Just using first 2 rows for testing
    for index, row in curr_plays_df.iterrows(): #Just using first 2 rows for testing

        # saw playEvents is a nested list, so json_normalize it
        play_events_df = json_normalize(row['playEvents'])

        #     # look at runners
        #     runners_df = json_normalize(row['runners'])

        # Loop through THIS NESTED dataframe and NOW build the row for the new df    
        for plev_ind, plev_row in play_events_df.iterrows():

            # Instantiate new dict, which will be a single row in target df
            curr_dict = {}

            curr_dict['_pitch_id'] = str(game) + '_' +\
                str(row['about.atBatIndex']) + '_' +\
                str(i)
            
            curr_dict['_prior_pitch_id'] = str(game) + '_' +\
                str(row['about.atBatIndex']) + '_' +\
                str(i-1)
           
            # Loop through each list, adding their respective values to curr_dict
            for col_ap in ap_sel_cols:
                if col_ap in curr_plays_df.columns:
                    curr_dict[col_ap] = row[col_ap]
                else:
                    curr_dict[col_ap] = np.nan
                #print(row['about.atBatIndex'])

            for col_plev in plev_sel_cols:
                if col_plev in play_events_df.columns:
                    curr_dict[col_plev] = plev_row[col_plev]
                else:
                    curr_dict[col_plev] = np.nan

            # collect row dictionary into list
            list_for_new_df.append(curr_dict)
            
            i +=1

# %% [markdown]
# We have gathered and organzied 49 Seattle Mariner games from the 2019 season. The only games not included are the games from March 20th to March 23, which were played in Japan before MLB's official opening day

# %%
# Proof of concept on target dataframe
pitches_df = pd.DataFrame(list_for_new_df)
print(len(pitches_df))

pitches_df.head(1)
# Out:
# 625
#     _pitch_id _prior_pitch_id  about.atBatIndex about.halfInning  \
# 0  529448_0_1      529448_0_0                 0              top
#
#    about.inning  count.balls  count.outs  count.strikes details.type.code  \
# 0             1            0           0              0                SI
#
#   details.type.description  isPitch matchup.batSide.code  \
# 0                   Sinker     True                    L
#
#   matchup.pitchHand.code matchup.splits.menOnBase  pitchNumber  \
# 0                      R                   Men_On          1.0
#
#    result.awayScore  result.homeScore
# 0                 0                 0

# %%
pitches_df_prior = pitches_df.loc[:,['_pitch_id','details.type.code']]
pitches_df_prior.columns = ['_pitch_id_temp','prior_pitch_cd']

# %%
pitches_df_join = pd.merge(pitches_df, pitches_df_prior, how='left'
                          ,left_on='_prior_pitch_id', right_on='_pitch_id_temp')

# %%
pitches_df_join.shape
# Out:
# (625, 19)

# %%
pitches_df_join.head(40)
# Out:
#       _pitch_id _prior_pitch_id  about.atBatIndex about.halfInning  \
# 0    529448_0_1      529448_0_0                 0              top
# 1    529448_1_2      529448_1_1                 1              top
# 2    529448_1_3      529448_1_2                 1              top
# 3    529448_1_4      529448_1_3                 1              top
# 4    529448_1_5      529448_1_4                 1              top
# 5    529448_1_6      529448_1_5                 1              top
# 6    529448_1_7      529448_1_6                 1              top
# 7    529448_1_8      529448_1_7                 1              top
# 8    529448_1_9      529448_1_8                 1              top
# 9   529448_1_10      529448_1_9                 1              top
# 10  529448_2_11     529448_2_10                 2              top
# 11  529448_2_12     529448_2_11                 2              top
# 12  529448_2_13     529448_2_12                 2              top
# 13  529448_3_14     529448_3_13                 3              top
# 14  529448_3_15     529448_3_14                 3              top
# 15  529448_3_16     529448_3_15                 3              top
# 16  529448_3_17     529448_3_16                 3              top
# 17  529448_3_18     529448_3_17                 3              top
# 18  529448_4_19     529448_4_18                 4           bottom
# 19  529448_4_20     529448_4_19                 4           bottom
# 20  529448_4_21     529448_4_20                 4           bottom
# 21  529448_4_22     529448_4_21                 4           bottom
# 22  529448_4_23     529448_4_22                 4           bottom
# 23  529448_4_24     529448_4_23                 4           bottom
# 24  529448_4_25     529448_4_24                 4           bottom
# 25  529448_5_26     529448_5_25                 5           bottom
# 26  529448_6_27     529448_6_26                 6           bottom
# 27  529448_6_28     529448_6_27                 6           bottom
# 28  529448_6_29     529448_6_28                 6           bottom
# 29  529448_7_30     529448_7_29                 7           bottom
# 30  529448_7_31     529448_7_30                 7           bottom
# 31  529448_7_32     529448_7_31                 7           bottom
# 32  529448_7_33     529448_7_32                 7           bottom
# 33  529448_7_34     529448_7_33                 7           bottom
# 34  529448_7_35     529448_7_34                 7           bottom
# 35  529448_8_36     529448_8_35                 8              top
# 36  529448_8_37     529448_8_36                 8              top
# 37  529448_8_38     529448_8_37                 8              top
# 38  529448_8_39     529448_8_38                 8              top
# 39  529448_8_40     529448_8_39                 8              top
#
#     about.inning  count.balls  count.outs  count.strikes details.type.code  \
# 0              1            0           0              0                SI
# 1              1            2           1              3                SI
# 2              1            2           1              3                CH
# 3              1            2           1              3               NaN
# 4              1            2           1              3               NaN
# 5              1            2           1              3                FC
# 6              1            2           1              3                FF
# 7              1            2           1              3                KC
# 8              1            2           1              3               NaN
# 9              1            2           1              3                FF
# 10             1            1           2              1                FF
# 11             1            1           2              1                FF
# 12             1            1           2              1                CH
# 13             1            3           3              1                CH
# 14             1            3           3              1                CH
# 15             1            3           3              1                KC
# 16             1            3           3              1                SI
# 17             1            3           3              1                CH
# 18             1            3           1              3                FF
# 19             1            3           1              3                FF
# 20             1            3           1              3                FF
# 21             1            3           1              3                SL
# 22             1            3           1              3                FT
# 23             1            3           1              3                KC
# 24             1            3           1              3                FF
# 25             1            0           2              0                FF
# 26             1            1           2              1                FF
# 27             1            1           2              1                FC
# 28             1            1           2              1                KC
# 29             1            2           3              2                FF
# 30             1            2           3              2                KC
# 31             1            2           3              2                SL
# 32             1            2           3              2                KC
# 33             1            2           3              2                FF
# 34             1            2           3              2                SL
# 35             2            2           1              3                SI
# 36             2            2           1              3                CH
# 37             2            2           1              3                SL
# 38             2            2           1              3                FC
# 39             2            2           1              3                SI
#
#    details.type.description  isPitch matchup.batSide.code  \
# 0                    Sinker     True                    L
# 1                    Sinker     True                    L
# 2                  Changeup     True                    L
# 3                       NaN    False                    L
# 4                       NaN    False                    L
# 5                    Cutter     True                    L
# 6        Four-Seam Fastball     True                    L
# 7             Knuckle Curve     True                    L
# 8                       NaN    False                    L
# 9        Four-Seam Fastball     True                    L
# 10       Four-Seam Fastball     True                    L
# 11       Four-Seam Fastball     True                    L
# 12                 Changeup     True                    L
# 13                 Changeup     True                    L
# 14                 Changeup     True                    L
# 15            Knuckle Curve     True                    L
# 16                   Sinker     True                    L
# 17                 Changeup     True                    L
# 18       Four-Seam Fastball     True                    L
# 19       Four-Seam Fastball     True                    L
# 20       Four-Seam Fastball     True                    L
# 21                   Slider     True                    L
# 22        Two-Seam Fastball     True                    L
# 23            Knuckle Curve     True                    L
# 24       Four-Seam Fastball     True                    L
# 25       Four-Seam Fastball     True                    R
# 26       Four-Seam Fastball     True                    L
# 27                   Cutter     True                    L
# 28            Knuckle Curve     True                    L
# 29       Four-Seam Fastball     True                    R
# 30            Knuckle Curve     True                    R
# 31                   Slider     True                    R
# 32            Knuckle Curve     True                    R
# 33       Four-Seam Fastball     True                    R
# 34                   Slider     True                    R
# 35                   Sinker     True                    R
# 36                 Changeup     True                    R
# 37                   Slider     True                    R
# 38                   Cutter     True                    R
# 39                   Sinker     True                    R
#
#    matchup.pitchHand.code matchup.splits.menOnBase  pitchNumber  \
# 0                       R                   Men_On          1.0
# 1                       R                     RISP          1.0
# 2                       R                     RISP          2.0
# 3                       R                     RISP          NaN
# 4                       R                     RISP          NaN
# 5                       R                     RISP          3.0
# 6                       R                     RISP          4.0
# 7                       R                     RISP          5.0
# 8                       R                     RISP          NaN
# 9                       R                     RISP          6.0
# 10                      R                     RISP          1.0
# 11                      R                     RISP          2.0
# 12                      R                     RISP          3.0
# 13                      R                    Empty          1.0
# 14                      R                    Empty          2.0
# 15                      R                    Empty          3.0
# 16                      R                    Empty          4.0
# 17                      R                    Empty          5.0
# 18                      R                    Empty          1.0
# 19                      R                    Empty          2.0
# 20                      R                    Empty          3.0
# 21                      R                    Empty          4.0
# 22                      R                    Empty          5.0
# 23                      R                    Empty          6.0
# 24                      R                    Empty          7.0
# 25                      R                    Empty          1.0
# 26                      R                     RISP          1.0
# 27                      R                     RISP          2.0
# 28                      R                     RISP          3.0
# 29                      R                    Empty          1.0
# 30                      R                    Empty          2.0
# 31                      R                    Empty          3.0
# 32                      R                    Empty          4.0
# 33                      R                    Empty          5.0
# 34                      R                    Empty          6.0
# 35                      R                    Empty          1.0
# 36                      R                    Empty          2.0
# 37                      R                    Empty          3.0
# 38                      R                    Empty          4.0
# 39                      R                    Empty          5.0
#
#     result.awayScore  result.homeScore _pitch_id_temp prior_pitch_cd
# 0                  0                 0            NaN            NaN
# 1                  0                 0            NaN            NaN
# 2                  0                 0     529448_1_2             SI
# 3                  0                 0     529448_1_3             CH
# 4                  0                 0     529448_1_4            NaN
# 5                  0                 0     529448_1_5            NaN
# 6                  0                 0     529448_1_6             FC
# 7                  0                 0     529448_1_7             FF
# 8                  0                 0     529448_1_8             KC
# 9                  0                 0     529448_1_9            NaN
# 10                 0                 0            NaN            NaN
# 11                 0                 0    529448_2_11             FF
# 12                 0                 0    529448_2_12             FF
# 13                 0                 0            NaN            NaN
# 14                 0                 0    529448_3_14             CH
# 15                 0                 0    529448_3_15             CH
# 16                 0                 0    529448_3_16             KC
# 17                 0                 0    529448_3_17             SI
# 18                 0                 0            NaN            NaN
# 19                 0                 0    529448_4_19             FF
# 20                 0                 0    529448_4_20             FF
# 21                 0                 0    529448_4_21             FF
# 22                 0                 0    529448_4_22             SL
# 23                 0                 0    529448_4_23             FT
# 24                 0                 0    529448_4_24             KC
# 25                 0                 0            NaN            NaN
# 26                 0                 0            NaN            NaN
# 27                 0                 0    529448_6_27             FF
# 28                 0                 0    529448_6_28             FC
# 29                 0                 0            NaN            NaN
# 30                 0                 0    529448_7_30             FF
# 31                 0                 0    529448_7_31             KC
# 32                 0                 0    529448_7_32             SL
# 33                 0                 0    529448_7_33             KC
# 34                 0                 0    529448_7_34             FF
# 35                 0                 0            NaN            NaN
# 36                 0                 0    529448_8_36             SI
# 37                 0                 0    529448_8_37             CH
# 38                 0                 0    529448_8_38             SL
# 39                 0                 0    529448_8_39             FC

# %%
pitches_df = pitches_df_join

# %%
pitches_df['details.type.code'].unique()
# Out:
# array(['SI', 'CH', nan, 'FC', 'FF', 'KC', 'SL', 'FT', 'CU'], dtype=object)

# %%
pitches_df['details.type.description'].unique()
# Out:
# array(['Sinker', 'Changeup', nan, 'Cutter', 'Four-Seam Fastball',
#        'Knuckle Curve', 'Slider', 'Two-Seam Fastball', 'Curveball'],
#       dtype=object)

# %%
pitch_dict = {'FF': 'Fastball'}

# %%
pitch_dict['FT'] = 'Fastball'
pitch_dict['FC']= 'Fastball'
pitch_dict['FS'] = 'Fastball'
pitch_dict['CH'] = 'Changeup'
pitch_dict['SI'] = 'Fastball'
pitch_dict['FT'] = 'Fastball'
pitch_dict['CU'] = 'Breaking Ball'
pitch_dict['SL'] = 'Breaking Ball'
pitch_dict['KC'] = 'Breaking Ball'
pitch_dict['nan'] = 'NA'

# %%
pitches_df['pitch_type'] = pitches_df['details.type.code'].map(pitch_dict)
pitches_df['pitch_type']
pitches_df.head(1)
# Out:
#     _pitch_id _prior_pitch_id  about.atBatIndex about.halfInning  \
# 0  529448_0_1      529448_0_0                 0              top
#
#    about.inning  count.balls  count.outs  count.strikes details.type.code  \
# 0             1            0           0              0                SI
#
#   details.type.description  isPitch matchup.batSide.code  \
# 0                   Sinker     True                    L
#
#   matchup.pitchHand.code matchup.splits.menOnBase  pitchNumber  \
# 0                      R                   Men_On          1.0
#
#    result.awayScore  result.homeScore _pitch_id_temp prior_pitch_cd pitch_type
# 0                 0                 0            NaN            NaN   Fastball

# %%
pitches_df['pitch_type_prior'] = pitches_df['prior_pitch_cd'].map(pitch_dict)
pitches_df['pitch_type_prior']
pitches_df.head(10)
# Out:
#      _pitch_id _prior_pitch_id  about.atBatIndex about.halfInning  \
# 0   529448_0_1      529448_0_0                 0              top
# 1   529448_1_2      529448_1_1                 1              top
# 2   529448_1_3      529448_1_2                 1              top
# 3   529448_1_4      529448_1_3                 1              top
# 4   529448_1_5      529448_1_4                 1              top
# 5   529448_1_6      529448_1_5                 1              top
# 6   529448_1_7      529448_1_6                 1              top
# 7   529448_1_8      529448_1_7                 1              top
# 8   529448_1_9      529448_1_8                 1              top
# 9  529448_1_10      529448_1_9                 1              top
#
#    about.inning  count.balls  count.outs  count.strikes details.type.code  \
# 0             1            0           0              0                SI
# 1             1            2           1              3                SI
# 2             1            2           1              3                CH
# 3             1            2           1              3               NaN
# 4             1            2           1              3               NaN
# 5             1            2           1              3                FC
# 6             1            2           1              3                FF
# 7             1            2           1              3                KC
# 8             1            2           1              3               NaN
# 9             1            2           1              3                FF
#
#   details.type.description       ...         matchup.batSide.code  \
# 0                   Sinker       ...                            L
# 1                   Sinker       ...                            L
# 2                 Changeup       ...                            L
# 3                      NaN       ...                            L
# 4                      NaN       ...                            L
# 5                   Cutter       ...                            L
# 6       Four-Seam Fastball       ...                            L
# 7            Knuckle Curve       ...                            L
# 8                      NaN       ...                            L
# 9       Four-Seam Fastball       ...                            L
#
#   matchup.pitchHand.code matchup.splits.menOnBase pitchNumber  \
# 0                      R                   Men_On         1.0
# 1                      R                     RISP         1.0
# 2                      R                     RISP         2.0
# 3                      R                     RISP         NaN
# 4                      R                     RISP         NaN
# 5                      R                     RISP         3.0
# 6                      R                     RISP         4.0
# 7                      R                     RISP         5.0
# 8                      R                     RISP         NaN
# 9                      R                     RISP         6.0
#
#    result.awayScore  result.homeScore  _pitch_id_temp prior_pitch_cd  \
# 0                 0                 0             NaN            NaN
# 1                 0                 0             NaN            NaN
# 2                 0                 0      529448_1_2             SI
# 3                 0                 0      529448_1_3             CH
# 4                 0                 0      529448_1_4            NaN
# 5                 0                 0      529448_1_5            NaN
# 6                 0                 0      529448_1_6             FC
# 7                 0                 0      529448_1_7             FF
# 8                 0                 0      529448_1_8             KC
# 9                 0                 0      529448_1_9            NaN
#
#       pitch_type pitch_type_prior
# 0       Fastball              NaN
# 1       Fastball              NaN
# 2       Changeup         Fastball
# 3            NaN         Changeup
# 4            NaN              NaN
# 5       Fastball              NaN
# 6       Fastball         Fastball
# 7  Breaking Ball         Fastball
# 8            NaN    Breaking Ball
# 9       Fastball              NaN
#
# [10 rows x 21 columns]

# %%
#Kick Out Pitch Number

# %%
clean_pitches = pitches_df.drop(['details.type.code', 'details.type.description'
                                 ,'isPitch', 'pitchNumber'
                                 ,'prior_pitch_cd'
                                 ,'_pitch_id_temp'
                                 ,'_pitch_id'
                                 ,'_prior_pitch_id'], axis=1)

# %%
clean_pitches
# Out:
#      about.atBatIndex about.halfInning  about.inning  count.balls  count.outs  \
# 0                   0              top             1            0           0
# 1                   1              top             1            2           1
# 2                   1              top             1            2           1
# 3                   1              top             1            2           1
# 4                   1              top             1            2           1
# 5                   1              top             1            2           1
# 6                   1              top             1            2           1
# 7                   1              top             1            2           1
# 8                   1              top             1            2           1
# 9                   1              top             1            2           1
# 10                  2              top             1            1           2
# 11                  2              top             1            1           2
# 12                  2              top             1            1           2
# 13                  3              top             1            3           3
# 14                  3              top             1            3           3
# 15                  3              top             1            3           3
# 16                  3              top             1            3           3
# 17                  3              top             1            3           3
# 18                  4           bottom             1            3           1
# 19                  4           bottom             1            3           1
# 20                  4           bottom             1            3           1
# 21                  4           bottom             1            3           1
# 22                  4           bottom             1            3           1
# 23                  4           bottom             1            3           1
# 24                  4           bottom             1            3           1
# 25                  5           bottom             1            0           2
# 26                  6           bottom             1            1           2
# 27                  6           bottom             1            1           2
# 28                  6           bottom             1            1           2
# 29                  7           bottom             1            2           3
# ..                ...              ...           ...          ...         ...
# 595                67           bottom             8            2           2
# 596                67           bottom             8            2           2
# 597                67           bottom             8            2           2
# 598                68           bottom             8            1           3
# 599                68           bottom             8            1           3
# 600                68           bottom             8            1           3
# 601                69              top             9            1           1
# 602                69              top             9            1           1
# 603                69              top             9            1           1
# 604                69              top             9            1           1
# 605                69              top             9            1           1
# 606                69              top             9            1           1
# 607                70              top             9            0           2
# 608                70              top             9            0           2
# 609                70              top             9            0           2
# 610                71              top             9            0           3
# 611                72           bottom             9            1           1
# 612                72           bottom             9            1           1
# 613                72           bottom             9            1           1
# 614                72           bottom             9            1           1
# 615                72           bottom             9            1           1
# 616                72           bottom             9            1           1
# 617                73           bottom             9            1           2
# 618                73           bottom             9            1           2
# 619                73           bottom             9            1           2
# 620                73           bottom             9            1           2
# 621                74           bottom             9            2           3
# 622                74           bottom             9            2           3
# 623                74           bottom             9            2           3
# 624                74           bottom             9            2           3
#
#      count.strikes matchup.batSide.code matchup.pitchHand.code  \
# 0                0                    L                      R
# 1                3                    L                      R
# 2                3                    L                      R
# 3                3                    L                      R
# 4                3                    L                      R
# 5                3                    L                      R
# 6                3                    L                      R
# 7                3                    L                      R
# 8                3                    L                      R
# 9                3                    L                      R
# 10               1                    L                      R
# 11               1                    L                      R
# 12               1                    L                      R
# 13               1                    L                      R
# 14               1                    L                      R
# 15               1                    L                      R
# 16               1                    L                      R
# 17               1                    L                      R
# 18               3                    L                      R
# 19               3                    L                      R
# 20               3                    L                      R
# 21               3                    L                      R
# 22               3                    L                      R
# 23               3                    L                      R
# 24               3                    L                      R
# 25               0                    R                      R
# 26               1                    L                      R
# 27               1                    L                      R
# 28               1                    L                      R
# 29               2                    R                      R
# ..             ...                  ...                    ...
# 595              2                    R                      R
# 596              2                    R                      R
# 597              2                    R                      R
# 598              1                    R                      R
# 599              1                    R                      R
# 600              1                    R                      R
# 601              3                    L                      R
# 602              3                    L                      R
# 603              3                    L                      R
# 604              3                    L                      R
# 605              3                    L                      R
# 606              3                    L                      R
# 607              3                    R                      R
# 608              3                    R                      R
# 609              3                    R                      R
# 610              0                    L                      R
# 611              3                    R                      R
# 612              3                    R                      R
# 613              3                    R                      R
# 614              3                    R                      R
# 615              3                    R                      R
# 616              3                    R                      R
# 617              3                    R                      R
# 618              3                    R                      R
# 619              3                    R                      R
# 620              3                    R                      R
# 621              1                    R                      R
# 622              1                    R                      R
# 623              1                    R                      R
# 624              1                    R                      R
#
#     matchup.splits.menOnBase  result.awayScore  result.homeScore  \
# 0                     Men_On                 0                 0
# 1                       RISP                 0                 0
# 2                       RISP                 0                 0
# 3                       RISP                 0                 0
# 4                       RISP                 0                 0
# 5                       RISP                 0                 0
# 6                       RISP                 0                 0
# 7                       RISP                 0                 0
# 8                       RISP                 0                 0
# 9                       RISP                 0                 0
# 10                      RISP                 0                 0
# 11                      RISP                 0                 0
# 12                      RISP                 0                 0
# 13                     Empty                 0                 0
# 14                     Empty                 0                 0
# 15                     Empty                 0                 0
# 16                     Empty                 0                 0
# 17                     Empty                 0                 0
# 18                     Empty                 0                 0
# 19                     Empty                 0                 0
# 20                     Empty                 0                 0
# 21                     Empty                 0                 0
# 22                     Empty                 0                 0
# 23                     Empty                 0                 0
# 24                     Empty                 0                 0
# 25                     Empty                 0                 0
# 26                      RISP                 0                 0
# 27                      RISP                 0                 0
# 28                      RISP                 0                 0
# 29                     Empty                 0                 0
# ..                       ...               ...               ...
# 595                     RISP                 6                 4
# 596                     RISP                 6                 4
# 597                     RISP                 6                 4
# 598                    Empty                 6                 4
# 599                    Empty                 6                 4
# 600                    Empty                 6                 4
# 601                    Empty                 6                 4
# 602                    Empty                 6                 4
# 603                    Empty                 6                 4
# 604                    Empty                 6                 4
# 605                    Empty                 6                 4
# 606                    Empty                 6                 4
# 607                    Empty                 6                 4
# 608                    Empty                 6                 4
# 609                    Empty                 6                 4
# 610                    Empty                 6                 4
# 611                    Empty                 6                 4
# 612                    Empty                 6                 4
# 613                    Empty                 6                 4
# 614                    Empty                 6                 4
# 615                    Empty                 6                 4
# 616                    Empty                 6                 4
# 617                    Empty                 6                 4
# 618                    Empty                 6                 4
# 619                    Empty                 6                 4
# 620                    Empty                 6                 4
# 621                    Empty                 6                 4
# 622                    Empty                 6                 4
# 623                    Empty                 6                 4
# 624                    Empty                 6                 4
#
#         pitch_type pitch_type_prior
# 0         Fastball              NaN
# 1         Fastball              NaN
# 2         Changeup         Fastball
# 3              NaN         Changeup
# 4              NaN              NaN
# 5         Fastball              NaN
# 6         Fastball         Fastball
# 7    Breaking Ball         Fastball
# 8              NaN    Breaking Ball
# 9         Fastball              NaN
# 10        Fastball              NaN
# 11        Fastball         Fastball
# 12        Changeup         Fastball
# 13        Changeup              NaN
# 14        Changeup         Changeup
# 15   Breaking Ball         Changeup
# 16        Fastball    Breaking Ball
# 17        Changeup         Fastball
# 18        Fastball              NaN
# 19        Fastball         Fastball
# 20        Fastball         Fastball
# 21   Breaking Ball         Fastball
# 22        Fastball    Breaking Ball
# 23   Breaking Ball         Fastball
# 24        Fastball    Breaking Ball
# 25        Fastball              NaN
# 26        Fastball              NaN
# 27        Fastball         Fastball
# 28   Breaking Ball         Fastball
# 29        Fastball              NaN
# ..             ...              ...
# 595  Breaking Ball         Fastball
# 596  Breaking Ball    Breaking Ball
# 597       Fastball    Breaking Ball
# 598       Fastball              NaN
# 599       Fastball         Fastball
# 600       Fastball         Fastball
# 601            NaN              NaN
# 602            NaN              NaN
# 603       Fastball              NaN
# 604       Changeup         Fastball
# 605       Fastball         Changeup
# 606  Breaking Ball         Fastball
# 607  Breaking Ball              NaN
# 608  Breaking Ball    Breaking Ball
# 609  Breaking Ball    Breaking Ball
# 610       Changeup              NaN
# 611            NaN              NaN
# 612       Fastball              NaN
# 613  Breaking Ball         Fastball
# 614       Fastball    Breaking Ball
# 615       Fastball         Fastball
# 616  Breaking Ball         Fastball
# 617  Breaking Ball              NaN
# 618       Fastball    Breaking Ball
# 619       Fastball         Fastball
# 620       Fastball         Fastball
# 621       Fastball              NaN
# 622  Breaking Ball         Fastball
# 623  Breaking Ball    Breaking Ball
# 624       Fastball    Breaking Ball
#
# [625 rows x 13 columns]

# %%
clean_pitches['run_differential'] = (clean_pitches['result.homeScore'] - clean_pitches['result.awayScore']) * ((clean_pitches['about.halfInning'] == 'top') *1 - (clean_pitches['about.halfInning']== 'bottom') * 1)

# %%
clean_pitches.head(5
                  )
# Out:
#    about.atBatIndex about.halfInning  about.inning  count.balls  count.outs  \
# 0                 0              top             1            0           0
# 1                 1              top             1            2           1
# 2                 1              top             1            2           1
# 3                 1              top             1            2           1
# 4                 1              top             1            2           1
#
#    count.strikes matchup.batSide.code matchup.pitchHand.code  \
# 0              0                    L                      R
# 1              3                    L                      R
# 2              3                    L                      R
# 3              3                    L                      R
# 4              3                    L                      R
#
#   matchup.splits.menOnBase  result.awayScore  result.homeScore pitch_type  \
# 0                   Men_On                 0                 0   Fastball
# 1                     RISP                 0                 0   Fastball
# 2                     RISP                 0                 0   Changeup
# 3                     RISP                 0                 0        NaN
# 4                     RISP                 0                 0        NaN
#
#   pitch_type_prior  run_differential
# 0              NaN                 0
# 1              NaN                 0
# 2         Fastball                 0
# 3         Changeup                 0
# 4              NaN                 0

# %% [markdown]
# # EDA

# %% [markdown]
# Dropping NA values in order to visualize data

# %%
pitches_df_clean = clean_pitches.dropna(axis=0)

# %%
sns.countplot(x='pitch_type', hue='matchup.splits.menOnBase', data=pitches_df_clean)

# %%
sns.countplot(x='count.outs', hue='pitch_type', data=pitches_df_clean)

# %%
cropped_pitches = pitches_df_clean.drop(['count.outs', 'count.strikes', 'count.balls'], axis=1)
cropped_pitches
# Out:
#      about.atBatIndex about.halfInning  about.inning matchup.batSide.code  \
# 2                   1              top             1                    L
# 6                   1              top             1                    L
# 7                   1              top             1                    L
# 11                  2              top             1                    L
# 12                  2              top             1                    L
# 14                  3              top             1                    L
# 15                  3              top             1                    L
# 16                  3              top             1                    L
# 17                  3              top             1                    L
# 19                  4           bottom             1                    L
# 20                  4           bottom             1                    L
# 21                  4           bottom             1                    L
# 22                  4           bottom             1                    L
# 23                  4           bottom             1                    L
# 24                  4           bottom             1                    L
# 27                  6           bottom             1                    L
# 28                  6           bottom             1                    L
# 30                  7           bottom             1                    R
# 31                  7           bottom             1                    R
# 32                  7           bottom             1                    R
# 33                  7           bottom             1                    R
# 34                  7           bottom             1                    R
# 36                  8              top             2                    R
# 37                  8              top             2                    R
# 38                  8              top             2                    R
# 39                  8              top             2                    R
# 41                  9              top             2                    L
# 43                 10              top             2                    R
# 44                 10              top             2                    R
# 45                 10              top             2                    R
# ..                ...              ...           ...                  ...
# 581                65           bottom             8                    R
# 582                65           bottom             8                    R
# 583                65           bottom             8                    R
# 586                66           bottom             8                    L
# 587                66           bottom             8                    L
# 588                66           bottom             8                    L
# 589                66           bottom             8                    L
# 590                66           bottom             8                    L
# 591                66           bottom             8                    L
# 594                67           bottom             8                    R
# 595                67           bottom             8                    R
# 596                67           bottom             8                    R
# 597                67           bottom             8                    R
# 599                68           bottom             8                    R
# 600                68           bottom             8                    R
# 604                69              top             9                    L
# 605                69              top             9                    L
# 606                69              top             9                    L
# 608                70              top             9                    R
# 609                70              top             9                    R
# 613                72           bottom             9                    R
# 614                72           bottom             9                    R
# 615                72           bottom             9                    R
# 616                72           bottom             9                    R
# 618                73           bottom             9                    R
# 619                73           bottom             9                    R
# 620                73           bottom             9                    R
# 622                74           bottom             9                    R
# 623                74           bottom             9                    R
# 624                74           bottom             9                    R
#
#     matchup.pitchHand.code matchup.splits.menOnBase  result.awayScore  \
# 2                        R                     RISP                 0
# 6                        R                     RISP                 0
# 7                        R                     RISP                 0
# 11                       R                     RISP                 0
# 12                       R                     RISP                 0
# 14                       R                    Empty                 0
# 15                       R                    Empty                 0
# 16                       R                    Empty                 0
# 17                       R                    Empty                 0
# 19                       R                    Empty                 0
# 20                       R                    Empty                 0
# 21                       R                    Empty                 0
# 22                       R                    Empty                 0
# 23                       R                    Empty                 0
# 24                       R                    Empty                 0
# 27                       R                     RISP                 0
# 28                       R                     RISP                 0
# 30                       R                    Empty                 0
# 31                       R                    Empty                 0
# 32                       R                    Empty                 0
# 33                       R                    Empty                 0
# 34                       R                    Empty                 0
# 36                       R                    Empty                 0
# 37                       R                    Empty                 0
# 38                       R                    Empty                 0
# 39                       R                    Empty                 0
# 41                       R                   Men_On                 0
# 43                       R                     RISP                 0
# 44                       R                     RISP                 0
# 45                       R                     RISP                 0
# ..                     ...                      ...               ...
# 581                      R                   Men_On                 6
# 582                      R                   Men_On                 6
# 583                      R                   Men_On                 6
# 586                      R                     RISP                 6
# 587                      R                     RISP                 6
# 588                      R                     RISP                 6
# 589                      R                     RISP                 6
# 590                      R                     RISP                 6
# 591                      R                     RISP                 6
# 594                      R                     RISP                 6
# 595                      R                     RISP                 6
# 596                      R                     RISP                 6
# 597                      R                     RISP                 6
# 599                      R                    Empty                 6
# 600                      R                    Empty                 6
# 604                      R                    Empty                 6
# 605                      R                    Empty                 6
# 606                      R                    Empty                 6
# 608                      R                    Empty                 6
# 609                      R                    Empty                 6
# 613                      R                    Empty                 6
# 614                      R                    Empty                 6
# 615                      R                    Empty                 6
# 616                      R                    Empty                 6
# 618                      R                    Empty                 6
# 619                      R                    Empty                 6
# 620                      R                    Empty                 6
# 622                      R                    Empty                 6
# 623                      R                    Empty                 6
# 624                      R                    Empty                 6
#
#      result.homeScore     pitch_type pitch_type_prior  run_differential
# 2                   0       Changeup         Fastball                 0
# 6                   0       Fastball         Fastball                 0
# 7                   0  Breaking Ball         Fastball                 0
# 11                  0       Fastball         Fastball                 0
# 12                  0       Changeup         Fastball                 0
# 14                  0       Changeup         Changeup                 0
# 15                  0  Breaking Ball         Changeup                 0
# 16                  0       Fastball    Breaking Ball                 0
# 17                  0       Changeup         Fastball                 0
# 19                  0       Fastball         Fastball                 0
# 20                  0       Fastball         Fastball                 0
# 21                  0  Breaking Ball         Fastball                 0
# 22                  0       Fastball    Breaking Ball                 0
# 23                  0  Breaking Ball         Fastball                 0
# 24                  0       Fastball    Breaking Ball                 0
# 27                  0       Fastball         Fastball                 0
# 28                  0  Breaking Ball         Fastball                 0
# 30                  0  Breaking Ball         Fastball                 0
# 31                  0  Breaking Ball    Breaking Ball                 0
# 32                  0  Breaking Ball    Breaking Ball                 0
# 33                  0       Fastball    Breaking Ball                 0
# 34                  0  Breaking Ball         Fastball                 0
# 36                  0       Changeup         Fastball                 0
# 37                  0  Breaking Ball         Changeup                 0
# 38                  0       Fastball    Breaking Ball                 0
# 39                  0       Fastball         Fastball                 0
# 41                  0       Fastball         Fastball                 0
# 43                  0       Fastball         Fastball                 0
# 44                  0       Fastball         Fastball                 0
# 45                  0  Breaking Ball         Fastball                 0
# ..                ...            ...              ...               ...
# 581                 4       Fastball    Breaking Ball                 2
# 582                 4       Fastball         Fastball                 2
# 583                 4  Breaking Ball         Fastball                 2
# 586                 4       Fastball         Fastball                 2
# 587                 4       Fastball         Fastball                 2
# 588                 4       Fastball         Fastball                 2
# 589                 4       Fastball         Fastball                 2
# 590                 4       Fastball         Fastball                 2
# 591                 4       Fastball         Fastball                 2
# 594                 4       Fastball         Fastball                 2
# 595                 4  Breaking Ball         Fastball                 2
# 596                 4  Breaking Ball    Breaking Ball                 2
# 597                 4       Fastball    Breaking Ball                 2
# 599                 4       Fastball         Fastball                 2
# 600                 4       Fastball         Fastball                 2
# 604                 4       Changeup         Fastball                -2
# 605                 4       Fastball         Changeup                -2
# 606                 4  Breaking Ball         Fastball                -2
# 608                 4  Breaking Ball    Breaking Ball                -2
# 609                 4  Breaking Ball    Breaking Ball                -2
# 613                 4  Breaking Ball         Fastball                 2
# 614                 4       Fastball    Breaking Ball                 2
# 615                 4       Fastball         Fastball                 2
# 616                 4  Breaking Ball         Fastball                 2
# 618                 4       Fastball    Breaking Ball                 2
# 619                 4       Fastball         Fastball                 2
# 620                 4       Fastball         Fastball                 2
# 622                 4  Breaking Ball         Fastball                 2
# 623                 4  Breaking Ball    Breaking Ball                 2
# 624                 4       Fastball    Breaking Ball                 2
#
# [411 rows x 11 columns]

# %% [markdown]
# # Model 1: 2019 Seattle Mariners Pitch Data(49 Games)

# %%
new_pitches = cropped_pitches.dropna().copy()
print(new_pitches.shape)
new_pitches.head()
# Out:
# (411, 11)
#     about.atBatIndex about.halfInning  about.inning matchup.batSide.code  \
# 2                  1              top             1                    L
# 6                  1              top             1                    L
# 7                  1              top             1                    L
# 11                 2              top             1                    L
# 12                 2              top             1                    L
#
#    matchup.pitchHand.code matchup.splits.menOnBase  result.awayScore  \
# 2                       R                     RISP                 0
# 6                       R                     RISP                 0
# 7                       R                     RISP                 0
# 11                      R                     RISP                 0
# 12                      R                     RISP                 0
#
#     result.homeScore     pitch_type pitch_type_prior  run_differential
# 2                  0       Changeup         Fastball                 0
# 6                  0       Fastball         Fastball                 0
# 7                  0  Breaking Ball         Fastball                 0
# 11                 0       Fastball         Fastball                 0
# 12                 0       Changeup         Fastball                 0

# %%
target = new_pitches['pitch_type']

# %%
predictors = new_pitches.drop(['pitch_type'], axis=1).copy()

# %% [markdown]
# We decided to create a pipeline to make our code more efficient. We will be able to feature engineer and then apply our data to the pipeline and it will give us our most productive model.

# %%
numeric_features = list(predictors.select_dtypes(exclude='object'))
numeric_transformer = Pipeline(steps=[('keeper', None)])

# %%
cat_features = list(predictors.select_dtypes(include='object'))
cat_transfomer = Pipeline(steps=[('onehot', OneHotEncoder())])

# %%
preprocessor = ColumnTransformer(transformers=[('num', numeric_transformer, numeric_features),
                                              ('cat', cat_transfomer, cat_features)])

# %%
classifiers = [DecisionTreeClassifier(), RandomForestClassifier(n_estimators=100, max_depth=5), 
               GradientBoostingClassifier(n_estimators=100), xgb.XGBClassifier()]

# %%
X_train, X_test, y_train, y_test = train_test_split(predictors, target, random_state=10)

# %%
for classifier in classifiers:
    clf1 = Pipeline(steps=[('preprocessor', preprocessor),
                          ('classifier', classifier)])
    clf1.fit(X_train, y_train)
    one_hot_names = list(clf1.named_steps['preprocessor'].transformers_[1][1].named_steps['onehot'].get_feature_names())
    final_feats = numeric_features + one_hot_names
    print(classifier)
    print('\n')
    print('Training Metrics')
    pitch_functions.calc_acc_and_f1_score(y_train, clf1.predict(X_train))
    print('\n')
    print('Testing Metrics')
    pitch_functions.calc_acc_and_f1_score(y_test, clf1.predict(X_test))
    print('\n')
    
    ifeats = clf1.named_steps['classifier'].feature_importances_
    feature_importance = pd.DataFrame(ifeats, index=final_feats,
                                 columns = ['importance']).sort_values('importance', ascending=False)

    fig, ax = plt.subplots(figsize=(10,10))

    ax.barh(feature_importance.head(10).index, width=feature_importance.head(10).importance)
    plt.gca().invert_yaxis()
    plt.title('Feature Importance')
    plt.xlabel('Relative Importance')
    plt.ylabel('Features')
    plt.show()
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
#
#
# Training Metrics
# Accuracy:0.805
# F1-Score: 0.809
# AUC: 0.866
#
#
# Testing Metrics
# Accuracy:0.408
# F1-Score: 0.413
# AUC: 0.515
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
#
# Training Metrics
# Accuracy:0.633
# F1-Score: 0.537
# AUC: 0.559
#
#
# Testing Metrics
# Accuracy:0.524
# F1-Score: 0.395
# AUC: 0.508
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=None,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)
#
#
# Training Metrics
# Accuracy:0.756
# F1-Score: 0.744
# AUC: 0.743
#
#
# Testing Metrics
# Accuracy:0.447
# F1-Score: 0.407
# AUC: 0.492
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='multi:softprob', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)
#
#
# Training Metrics
# Accuracy:0.701
# F1-Score: 0.670
# AUC: 0.668
#
#
# Testing Metrics
# Accuracy:0.485
# F1-Score: 0.430
# AUC: 0.511

# %% [markdown]
# ---

# %% [markdown]
# ## Data Storage

# %% [markdown]
# Now that we have our data, let's store it in a PostgreSQL db on AWS so we don't have to keep rebuilding it.

# %% [markdown]
# ### 1. Use SQLAlchemy to create PSQL engine:

# %%
# dialect+driver://username:password@host:port/database

sql_alc_engine = create_engine('postgresql://dsaf:dsaf040119@flatiron-projects.\
cy8jwdkpepr0.us-west-2.rds.amazonaws.com/flatiron')

# %% [markdown]
# ### 2. Use `pandas.to_sql` to write the `pitches_df` dataframe to the PostgreSQL database, using the SQLAlchemy engine.

# %%
pitches_df.to_sql('pitches', sql_alc_engine)

# %% [markdown]
# ### 3. Check that the table was created.

# %%
# Setup PSQL connection
conn = psql.connect(
    database="flatiron",
    user="dsaf",
    password="dsaf040119",
    host="flatiron-projects.cy8jwdkpepr0.us-west-2.rds.amazonaws.com",
    port='5432'
)

# %%
# Set up query
query = """
    SELECT * FROM pitches;
"""

# %%
# Instantiate cursor
cur = conn.cursor()

# %%
# Execute the query
cur.execute(query)

# %%
# Check results
pitches_df_clone = pd.DataFrame(cur.fetchall())
pitches_df_clone.columns = [col.name for col in cur.description]

# %%
pitches_df_clone.head()

# %%
pitches_df.tail(7)

# %%
pitches_df_clone.drop(['index'], axis=1, inplace=True)

# %%
pitches_df_clone.tail(7)

# %%
pitches_df.equals(pitches_df)

# %%
pitches_df.info()

# %%
pitches_df_clone.info()

# %%
pitches_df_clone.shape

# %% [markdown]
# Ah, it seems that `NaN` got transformed to None in the migration to PSQL and come back as such.

# %%
pitches_df.loc[pitches_df['details.call.code'].isna() ].shape

# %%
# Let's try to find the Nones
pitches_df_clone.loc[pitches_df_clone['details.call.code'].isna() ].shape

# %%
pitches_df['details.call.code'] == pitches_df_clone['details.call.code']

# %%
pitches_df_clone['details.call.code'].value_counts()

# %%
142+123+53

# %%
import numpy as np

# %%
pitches_df_clone.replace([None], np.nan, inplace=True)

# %%
pitches_df_clone.tail(7)

# %%
pitches_df_clone.info()

# %%
pitches_df == pitches_df_clone

# %% [markdown]
# ---

# %% [markdown]
# # Notes / To Dos

# %% [markdown]
# ### 1. Need to incorporate work to create list of desired games. Likely will require looping through list.

# %% [markdown]
# ### 2. Should this data be written out to a database, e.g. SQL or NoSQL?

# %% [markdown]
# ### 3. Other data to join? Team Characteristics? Player characteristics? RISP??
